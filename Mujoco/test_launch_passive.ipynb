# %% [markdown]
# # Common Libraries

# %%
import mujoco, mujoco.viewer

# %% [markdown]
# # Model specification

# %%
xml = """
<mujoco>
  <worldbody>
    <geom name="red_box" type="box" size=".2 .2 .2" rgba="1 0 0 1"/>
    <geom name="green_sphere" pos=".2 .2 .2" size=".1" rgba="0 1 0 1"/>
  </worldbody>
</mujoco>
"""

# %% [markdown]
# # Initialize model and data

# %%
model = mujoco.MjModel.from_xml_string(xml)
data = mujoco.MjData(model)

# %%
viwer = mujoco.viewer.launch_passive(model, data)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 viwer = mujoco.viewer.launch_passive(model, data)
#
# File /opt/anaconda3/envs/MyoSuite/lib/python3.9/site-packages/mujoco/viewer.py:510, in launch_passive(model, data, key_callback, show_left_ui, show_right_ui)
#     508 else:
#     509   if not isinstance(_MJPYTHON, _MjPythonBase):
# --> 510     raise RuntimeError(
#     511         '`launch_passive` requires that the Python script be run under '
#     512         '`mjpython` on macOS'
#     513     )
#     514   _MJPYTHON.launch_on_ui_thread(
#     515       model,
#     516       data,
#    (...)
#     520       show_right_ui,
#     521   )
#     523 return handle_return.get()
#
# RuntimeError: `launch_passive` requires that the Python script be run under `mjpython` on macOS
