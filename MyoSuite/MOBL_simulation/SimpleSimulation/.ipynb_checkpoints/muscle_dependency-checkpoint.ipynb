# %% [markdown]
# # Common Libraries

# %%
import os, sys, shutil
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from matplotlib.gridspec import GridSpec
from ipywidgets import interact, IntSlider, FloatSlider, Layout, Button, Output, VBox, HBox

if shutil.which("nvidia-smi") is not None:
    os.environ["MUJOCO_GL"] = "egl"
import mujoco

# %% [markdown]
# # Custom Libraries

# %%
sys.path.append("/home/seojin/Seojin_commonTool/Module")
from biomechanics_util import get_mujoco_joints, get_simulated_img, get_dependent_joints

# %% [markdown]
# # Params

# %%
# model_path = "/home/seojin/biomechanics_tools/myoconverter/models/mjc/Arm26/arm26_cvt3.xml"
model_path = "/mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41/temp_cvt3.xml"
# model_path = "/home/seojin/biomechanics_tools/myo_sim/arm/myoarm.xml"
model_path = "/mnt/sdb2/DeepProprioception/Projects/DP01_mri/Myosuite/Model/scaled_model_cvt3_mocap.xml"
simulation_interval = 0.001

# %% [markdown]
# # Initialize model

# %%
model = mujoco.MjModel.from_xml_path(model_path)
model.opt.timestep = simulation_interval
joint_names = [model.joint(i).name for i in range(model.njnt)]
muscle_names = [model.actuator(i).name for i in range(model.nu)]

mj_data = mujoco.MjData(model)
mujoco.mj_resetDataKeyframe(model, mj_data, 0)
mj_data.ctrl[:] = 0.0
mj_data.act[:] = 0.0

mujoco.mj_forward(model, mj_data)

# Renderer
renderer = mujoco.Renderer(model, height=400, width=600)
scene_option = mujoco.MjvOption()
scene_option.frame = mujoco.mjtFrame.mjFRAME_WORLD

# Camera
camera = mujoco.MjvCamera()
camera.azimuth = 0
camera.elevation = -110
camera.distance = 2.0

renderer.update_scene(mj_data, camera=camera, scene_option=scene_option)
plt.imshow(renderer.render())

# %%
plt.plot(mj_data.qfrc_actuator)
plt.xticks(np.arange(len(joint_names)), joint_names, rotation = 90)
for j in range(model.njnt):
    name = model.joint(j).name
    adr = model.jnt_dofadr[j]
    dofnum = 1 if model.jnt_type[j] in [
        mujoco.mjtJoint.mjJNT_HINGE,
        mujoco.mjtJoint.mjJNT_SLIDE
    ] else 0
    if dofnum == 1:
        print(name, mj_data.qfrc_actuator[adr])
# Out:
# sternoclavicular_r2 -5.60756351717905e-15
# sternoclavicular_r3 -2.6123179587097885e-13
# unrotscap_r3 -2.1678032646186836
# unrotscap_r2 3.0238918718853216
# acromioclavicular_r2 3.2786550056614168
# acromioclavicular_r3 -1.0761151757675107
# acromioclavicular_r1 1.415695830214827
# unrothum_r1 7.4266165778298
# unrothum_r3 -41.284656786560625
# unrothum_r2 -38.94194676805187
# elv_angle -48.43508219650407
# shoulder_elv -30.261887003191724
# shoulder1_r2 -48.43508219650407
# shoulder_rot -48.43508219650407
# elbow_flexion -35.57066771047293
# pro_sup 15.335438820909955
# deviation -39.25229718764663
# flexion 91.7817488357802
# wrist_hand_r1 149.36221575905236
# wrist_hand_r3 110.65847827668908

# %%
plt.plot(mj_data.actuator_force)
plt.xticks(np.arange(len(muscle_names)), muscle_names, rotation = 90, size = 8)
None

# %%
"""
# Passive force
for i in range(model.nu):
    if model.actuator_biastype[i] == mujoco.mjtBias.mjBIAS_MUSCLE:
        model.actuator_biastype[i] = mujoco.mjtBias.mjBIAS_NONE
"""
# Out:
# '\n# Passive force\nfor i in range(model.nu):\n    if model.actuator_biastype[i] == mujoco.mjtBias.mjBIAS_MUSCLE:\n        model.actuator_biastype[i] = mujoco.mjtBias.mjBIAS_NONE\n'

# %%
joint_name = "elv_angle"
jnt_id = mujoco.mj_name2id(model, mujoco.mjtObj.mjOBJ_JOINT, joint_name)
dof_adr = model.jnt_dofadr[jnt_id]

sim_qpos = np.zeros_like(mj_data.qpos)
sim_qpos[dof_adr] = 0
mj_data.qpos[:] = sim_qpos

for i in range(model.nu):
    # Initialization
    mj_data.ctrl[:] = 0.0
    mj_data.act[:] = 0.0

    # Control
    mj_data.ctrl[i] = 1.0
    if model.actuator_dyntype[i] != mujoco.mjtDyn.mjDYN_NONE:
        act_adr = model.actuator_actadr[i]
        mj_data.act[act_adr] = 1.0

    # Simulation
    old_disableflags = model.opt.disableflags
    model.opt.disableflags |= mujoco.mjtDisableBit.mjDSBL_CONSTRAINT
    mujoco.mj_forward(model, mj_data)
    model.opt.disableflags = old_disableflags
    
    # History
    torque = mj_data.qfrc_actuator[dof_adr]

    # Analysis
    if abs(torque) > 1e-5:
        muscle_name = mujoco.mj_id2name(model, mujoco.mjtObj.mjOBJ_ACTUATOR, i)
        if not muscle_name:
            muscle_name = f"Actuator {i}"
            
        direction = "양(+) 방향 (올림 주동근)" if torque > 0 else "음(-) 방향 (내림 길항근)"
        print(f"근육명: {muscle_name:25} | 작용 방향: {direction:15} | 토크: {torque:8.4f}")
# Out:
# 근육명: DELT1                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -51.9754
# 근육명: DELT2                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -52.7748
# 근육명: DELT3                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -57.3549
# 근육명: SUPSP                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -58.1444
# 근육명: INFSP                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -91.8536
# 근육명: SUBSC                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -41.0273
# 근육명: TMIN                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -57.4300
# 근육명: TMAJ                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -52.8158
# 근육명: PECM1                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -49.9558
# 근육명: PECM2                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -49.1750
# 근육명: PECM3                     | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -54.5350
# 근육명: LAT1                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -50.1333
# 근육명: LAT2                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -54.0636
# 근육명: LAT3                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -54.5249
# 근육명: CORB                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.5893
# 근육명: TRIlong                   | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -58.3676
# 근육명: TRIlat                    | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: TRImed                    | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: ANC                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: SUP                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: BIClong                   | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -54.9514
# 근육명: BICshort                  | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -54.6777
# 근육명: BRA                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: BRD                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: ECRL                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: ECRB                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: ECU                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FCR                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FCU                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: PL                        | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: PT                        | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: PQ                        | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FDSL                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FDSR                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FDSM                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FDSI                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FDPL                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FDPR                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FDPM                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FDPI                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: EDCL                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: EDCR                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: EDCM                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: EDCI                      | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: EDM                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: EIP                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: EPL                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: EPB                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: FPL                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717
# 근육명: APL                       | 작용 방향: 음(-) 방향 (내림 길항근) | 토크: -55.7717

# %%
muscle_names = [mujoco.mj_id2name(model, mujoco.mjtObj.mjOBJ_ACTUATOR, i) for i in range(model.nu)]

# %%
import mujoco

# 확인하고 싶은 근육 이름 (예: 엄청난 힘을 내던 DELT1이나 INFSP 등)
target_muscles = muscle_names

print(f"{'근육명':<10} | {'최소길이':<10} | {'최대길이':<10} | {'현재길이':<10} | 상태")
print("-" * 65)

# 현재 역학 상태 업데이트 (qpos=0 등 현재 자세 기준)
mujoco.mj_kinematics(model, mj_data)

for muscle_name in target_muscles:
    # 1. 근육(액추에이터) ID 찾기
    act_id = mujoco.mj_name2id(model, mujoco.mjtObj.mjOBJ_ACTUATOR, muscle_name)
    
    if act_id == -1:
        print(f"{muscle_name} 근육을 찾을 수 없습니다.")
        continue
        
    # 2. XML에 정의된 근육 길이 범위 (model.actuator_lengthrange)
    length_range = model.actuator_lengthrange[act_id]
    min_length = length_range[0]
    max_length = length_range[1]
    
    # 3. 현재 자세에서의 실제 근육 길이 (mj_data.actuator_length)
    current_length = mj_data.actuator_length[act_id]
    
    # 4. 상태 분석 (현재 길이가 최대 길이에 얼마나 가까운지/넘었는지)
    status = "정상 (범위 내)"
    if current_length > max_length:
        status = "🚨 초과 (과도한 패시브 장력!)"
    elif current_length > max_length - (max_length - min_length) * 0.1:
        status = "⚠️ 한계 임박 (팽팽함)"
    elif current_length < min_length:
        status = "헐렁함 (Slack)"
        
    print(f"{muscle_name:<10} | {min_length:<10.4f} | {max_length:<10.4f} | {current_length:<10.4f} | {status}")
# Out:
# 근육명        | 최소길이       | 최대길이       | 현재길이       | 상태
# -----------------------------------------------------------------
# DELT1      | 0.1234     | 0.2431     | 0.2074     | 정상 (범위 내)
# DELT2      | 0.1358     | 0.2056     | 0.2373     | 🚨 초과 (과도한 패시브 장력!)
# DELT3      | 0.0717     | 0.1780     | 0.1545     | 정상 (범위 내)
# SUPSP      | 0.0716     | 0.1332     | 0.1124     | 정상 (범위 내)
# INFSP      | 0.0657     | 0.1363     | 0.1016     | 정상 (범위 내)
# SUBSC      | 0.0906     | 0.1273     | 0.1092     | 정상 (범위 내)
# TMIN       | 0.0946     | 0.1300     | 0.1262     | 정상 (범위 내)
# TMAJ       | 0.1022     | 0.2069     | 0.1363     | 정상 (범위 내)
# PECM1      | 0.0841     | 0.3355     | 0.1265     | 정상 (범위 내)
# PECM2      | 0.1793     | 0.2935     | 0.1775     | 헐렁함 (Slack)
# PECM3      | 0.1821     | 0.5728     | 0.1832     | 정상 (범위 내)
# LAT1       | 0.2221     | 0.3323     | 0.2565     | 정상 (범위 내)
# LAT2       | 0.2959     | 0.4123     | 0.3123     | 정상 (범위 내)
# LAT3       | 0.3237     | 0.4625     | 0.3407     | 정상 (범위 내)
# CORB       | 0.1391     | 0.2238     | 0.1476     | 정상 (범위 내)
# TRIlong    | 0.2610     | 0.3747     | 0.2776     | 정상 (범위 내)
# TRIlat     | 0.1666     | 0.2147     | 0.1666     | 정상 (범위 내)
# TRImed     | 0.1542     | 0.2023     | 0.1542     | 정상 (범위 내)
# ANC        | 0.0215     | 0.0476     | 0.0215     | 헐렁함 (Slack)
# SUP        | 0.0501     | 0.0752     | 0.0614     | 정상 (범위 내)
# BIClong    | 0.3153     | 0.4394     | 0.4307     | ⚠️ 한계 임박 (팽팽함)
# BICshort   | 0.2714     | 0.4202     | 0.3496     | 정상 (범위 내)
# BRA        | 0.1275     | 0.1459     | 0.1459     | 🚨 초과 (과도한 패시브 장력!)
# BRD        | 0.2008     | 0.3277     | 0.3310     | 🚨 초과 (과도한 패시브 장력!)
# ECRL       | 0.2859     | 0.3328     | 0.3282     | ⚠️ 한계 임박 (팽팽함)
# ECRB       | 0.2609     | 0.2959     | 0.2849     | 정상 (범위 내)
# ECU        | 0.2681     | 0.3075     | 0.2897     | 정상 (범위 내)
# FCR        | 0.2652     | 0.3252     | 0.3098     | 정상 (범위 내)
# FCU        | 0.2633     | 0.2895     | 0.3079     | 🚨 초과 (과도한 패시브 장력!)
# PL         | 0.2818     | 0.3698     | 0.3366     | 정상 (범위 내)
# PT         | 0.1243     | 0.1702     | 0.1551     | 정상 (범위 내)
# PQ         | 0.0220     | 0.0375     | 0.0312     | 정상 (범위 내)
# FDSL       | 0.4129     | 0.4720     | 0.4517     | 정상 (범위 내)
# FDSR       | 0.3925     | 0.4412     | 0.4441     | 🚨 초과 (과도한 패시브 장력!)
# FDSM       | 0.3734     | 0.4058     | 0.3878     | 정상 (범위 내)
# FDSI       | 0.3800     | 0.4081     | 0.3968     | 정상 (범위 내)
# FDPL       | 0.3731     | 0.3936     | 0.3825     | 정상 (범위 내)
# FDPR       | 0.3823     | 0.4036     | 0.3948     | 정상 (범위 내)
# FDPM       | 0.3991     | 0.4221     | 0.4126     | 정상 (범위 내)
# FDPI       | 0.3631     | 0.3951     | 0.3860     | 정상 (범위 내)
# EDCL       | 0.4125     | 0.4573     | 0.4325     | 정상 (범위 내)
# EDCR       | 0.4090     | 0.4756     | 0.4425     | 정상 (범위 내)
# EDCM       | 0.4178     | 0.4628     | 0.4465     | 정상 (범위 내)
# EDCI       | 0.4276     | 0.4755     | 0.4407     | 정상 (범위 내)
# EDM        | 0.4079     | 0.4433     | 0.4276     | 정상 (범위 내)
# EIP        | 0.2599     | 0.2996     | 0.2952     | 정상 (범위 내)
# EPL        | 0.2841     | 0.3065     | 0.2931     | 정상 (범위 내)
# EPB        | 0.1745     | 0.1943     | 0.1829     | 정상 (범위 내)
# FPL        | 0.2601     | 0.3150     | 0.3019     | 정상 (범위 내)
# APL        | 0.1829     | 0.2157     | 0.1979     | 정상 (범위 내)
