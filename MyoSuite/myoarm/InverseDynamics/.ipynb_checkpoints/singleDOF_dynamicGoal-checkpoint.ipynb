# %% [markdown]
# # Common Libraries

# %%
import os, sys, shutil, mediapy
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pylab as plt
from ipywidgets import interact

if shutil.which("nvidia-smi") is not None:
    os.environ["MUJOCO_GL"] = "egl"
import mujoco

# %% [markdown]
# # Custom Libraries

# %%
def get_indices(model, joint_name):
    jnt_id = model.joint(joint_name).id
    qpos_idx = model.jnt_qposadr[jnt_id]
    dof_idx = model.jnt_dofadr[jnt_id]
    return qpos_idx, dof_idx

# %%
def get_qfrc(model, data, target_qpos):
    """
    Compute the generalized force needed to reach the target position in the next mujoco step.
    """
    data_copy = mujoco.MjData(model)
    data_copy.qpos = data.qpos.copy()
    data_copy.qvel = data.qvel.copy()
    data_copy.qacc = (((target_qpos - data.qpos) / model.opt.timestep) - data.qvel) / model.opt.timestep
    model.opt.disableflags += mujoco.mjtDisableBit.mjDSBL_CONSTRAINT
    mujoco.mj_inverse(model, data_copy)
    model.opt.disableflags -= mujoco.mjtDisableBit.mjDSBL_CONSTRAINT
    return data_copy

def get_qfrc_stable(model, data, target_qpos):
    data_copy = mujoco.MjData(model)
    data_copy.qpos = data.qpos.copy()
    data_copy.qvel = data.qvel.copy()
    
    kp = 2500.0
    kd = 2.0 * np.sqrt(kp)
    data_copy.qacc = kp * (target_qpos - data.qpos) - kd * data.qvel
    
    model.opt.disableflags += mujoco.mjtDisableBit.mjDSBL_CONSTRAINT
    mujoco.mj_inverse(model, data_copy)
    model.opt.disableflags -= mujoco.mjtDisableBit.mjDSBL_CONSTRAINT
    
    return data_copy

# %% [markdown]
# # Params

# %%
model_path = "/home/seojin/biomechanics_tools/myo_sim/arm/myoarm.xml"

# %% [markdown]
# # Initialize model

# %%
model = mujoco.MjModel.from_xml_path(model_path)
simulation_timestep = model.opt.timestep

# Model constants
joint_names = [mujoco.mj_id2name(model, mujoco.mjtObj.mjOBJ_JOINT, idx) for idx in range(model.njnt)]
n_joint = len(joint_names)

# Joint indexing
shoulder_elevation_angle_q, shoulder_elevation_angle_d = get_indices(model, "shoulder_elv")

# Initialize pose
mj_data = mujoco.MjData(model)
mujoco.mj_forward(model, mj_data)

# %%
model.jnt_limited[:] = 0

# %% [markdown]
# # Renderer

# %%
# Renderer
renderer = mujoco.Renderer(model, height=400, width=600)
scene_option = mujoco.MjvOption()
scene_option.frame = mujoco.mjtFrame.mjFRAME_WORLD

# Camera
camera = mujoco.MjvCamera()
camera.azimuth = 90
camera.elevation = 0
camera.distance = 4
camera.lookat = [0,0,1.5]

# Initial render
renderer.update_scene(mj_data, camera=camera, scene_option=scene_option)
plt.imshow(renderer.render())

# %% [markdown]
# # Goal

# %%
final_goal_qpos = np.zeros(n_joint)
final_goal_qpos[shoulder_elevation_angle_q] = 1.6

# %%
goal_method = "jerk"

# %%
total_exp_time = 1 # second
n_sim = int(total_exp_time / simulation_timestep)

goal_qpos = np.zeros((n_sim, n_joint))
if goal_method == "discrete":
    goal_qpos[:, shoulder_elevation_angle_q] = np.linspace(0.0, final_goal_qpos[shoulder_elevation_angle_q], n_sim)
elif goal_method == "jerk":
    t = np.linspace(0, 1, n_sim)
    t_normalized = t / 1.0
    
    jerk_profile = 10 * (t_normalized**3) - 15 * (t_normalized**4) + 6 * (t_normalized**5)
    goal_qpos[:, shoulder_elevation_angle_q] = 0.0 + (final_goal_qpos[shoulder_elevation_angle_q] - 0.0) * jerk_profile

# %%
# Initialize start pose
mj_data = mujoco.MjData(model)
mujoco.mj_forward(model, mj_data)

# Image
pixels = np.zeros((n_sim, renderer.height, renderer.width, 3), dtype = np.uint8)

# Force
qposes = np.zeros((n_sim, model.nv))
qforces = np.zeros((n_sim, model.nv))
qfrc_bias = np.zeros((n_sim, model.nv))
qfrc_passive = np.zeros((n_sim, model.nv))
qfrc_constraint = np.zeros((n_sim, model.nv))

# Error
qerrors = pd.DataFrame(np.zeros((n_sim, n_joint)))
qerrors.columns = joint_names

# Simulation
for sim_i in tqdm(range(n_sim)):
    # Current
    current_qpos = mj_data.qpos.copy()
    current_qvel = mj_data.qvel.copy()
    
    # Control
    error_q = np.zeros(n_joint)
    error_q[shoulder_elevation_angle_q] = goal_qpos[sim_i, shoulder_elevation_angle_q] - current_qpos[shoulder_elevation_angle_q]
    qerrors.iloc[sim_i] = error_q

    # mj inverse
    force_data = get_qfrc(model, mj_data, goal_qpos[sim_i])
    mj_data.qfrc_applied[:] = force_data.qfrc_inverse
    
    qposes[sim_i, :] = current_qpos
    qforces[sim_i, :] = force_data.qfrc_inverse
    qfrc_bias[sim_i, :] = force_data.qfrc_bias
    qfrc_passive[sim_i, :] = force_data.qfrc_passive
    qfrc_constraint[sim_i, :] = force_data.qfrc_constraint
    
    # Forward dyanmics
    mujoco.mj_step(model, mj_data)

    # Rendering
    renderer.update_scene(mj_data, camera = camera, scene_option = scene_option)
    pixels[sim_i] = renderer.render()

qposes = pd.DataFrame(qposes)
qposes.columns = joint_names

qforces = pd.DataFrame(qforces)
qforces.columns = joint_names

qfrc_bias = pd.DataFrame(qfrc_bias)
qfrc_bias.columns = joint_names

qfrc_passive = pd.DataFrame(qfrc_passive)
qfrc_passive.columns = joint_names

qfrc_constraint = pd.DataFrame(qfrc_constraint)
qfrc_constraint.columns = joint_names
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 233.42it/s]

# %%
plt.plot(qposes["shoulder_elv"])

# %%
plt.plot(qforces["shoulder_elv"] / 100, label = "qforce")
plt.plot(qfrc_bias["shoulder_elv"], label = "qfrc_bias")
plt.plot(qfrc_passive["shoulder_elv"], label = "qfrc_passive")
plt.plot(qfrc_constraint["shoulder_elv"], label = "qfrc_constraint")
plt.legend()

# %%
mediapy.show_video(pixels, fps = 30, loop=False)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="600" height="400" style="object-fit:cover;" autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
# Plot parameters
n_cols = 5
n_rows = (len(joint_names) + n_cols - 1) // n_cols

# Plot
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 3), sharex=True)
axes = axes.flatten()
for i, joint_name in enumerate(joint_names):
    ax = axes[i]
    ax.plot(np.arange(0, n_sim), qforces[joint_name], color = "crimson", lw = 1.5, label = "sim")
    ax.set_title(joint_name, fontsize = 10)
    ax.grid(alpha = 0.3)
    ax.legend()

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
