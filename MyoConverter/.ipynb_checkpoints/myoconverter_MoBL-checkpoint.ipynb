# %% [markdown]
# # References
# - https://github.com/MyoHub/myoconverter

# %% [markdown]
# # Common Libraries

# %%
import os, sys

# myoconverter
if 'CONDA_PREFIX' not in os.environ:
    os.environ['CONDA_PREFIX'] = sys.prefix
myoconverter_path = "/home/seojin/myoconverter"
sys.path.append(myoconverter_path)
from myoconverter.O2MPipeline import O2MPipeline
import xml.etree.ElementTree as ET

# %% [markdown]
# # Custom Libraries

# %%
def extract_muscle_names(osim_file_path, tag = "Millard2012EquilibriumMuscle"):
    tree = ET.parse(osim_file_path)
    root = tree.getroot()

    muscle_names = []
    for muscle in root.iter(tag):
        name = muscle.get('name')
        if name:
            muscle_names.append(name)

    return muscle_names

# %% [markdown]
# # Paths

# %%
osim_dir_path = "/mnt/sdb2/DeepProprioception/OpenSim"

osim_file = os.path.join(osim_dir_path, "MOBL_ARMS_41_pointAligned.osim")
geometry_folder = os.path.join(osim_dir_path, "Geometry")
output_folder = "/mnt/ext1/seojin/temp/MOBL_aligned2"

# %% [markdown]
# # Params

# %%
# define pipeline configurations
kwargs = {}  # define kwargs inputs
kwargs['convert_steps'] = [1, 2, 3]    # All three steps selected
muscle_list = extract_muscle_names(osim_file)
muscle_list.remove("TMIN")
muscle_list.remove("EDCM")
kwargs['muscle_list'] = muscle_list           # No specific muscle selected, optimize all of them

kwargs['osim_data_overwrite'] = True   # Overwrite the Osim model state files
kwargs['conversion'] = True            # Yes, perform 'Cvt#' process
kwargs['validation'] = True            # Yes, perform 'Vlt#' process
kwargs['speedy'] = False               # Do not reduce the checking notes to increase speed
kwargs['generate_pdf'] = True          # Do not generate validation pdf report
kwargs['add_ground_geom'] = False       # Add ground to the model
kwargs['treat_as_normal_path_point'] = False    # Using constraints to represent moving and conditional path points

# %% [markdown]
# # Execution

# %%
############### Simple Arm 2 DoFs 6 Muscles ################ 
O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
# Out:
# 2026-04-23 00:56:09.574 | INFO     | myoconverter.O2MPipeline:O2MPipeline:52 - Start the conversion pipeline for : MOBL_ARMS_41_pointAligned
# 2026-04-23 00:56:09.575 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:75 - Coordinate the input configurations, remove conflicts.
# 2026-04-23 00:56:09.576 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:86 -    Checking configurations for step 2 conversion.
# 2026-04-23 00:56:09.576 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:101 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-04-23 00:56:09.577 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:103 -        All good now.
# 2026-04-23 00:56:09.578 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:119 -    Checking configurations for step 3 conversion.
# 2026-04-23 00:56:09.578 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:134 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-04-23 00:56:09.579 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:136 -        All good now.
# 2026-04-23 00:56:09.579 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:84 - Given OpenSim model file: /mnt/sdb2/DeepProprioception/OpenSim/MOBL_ARMS_41_pointAligned.osim
# 2026-04-23 00:56:09.580 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:85 - Reading mesh files from folder /mnt/sdb2/DeepProprioception/OpenSim/Geometry
# 2026-04-23 00:56:09.580 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:86 - Converted model will be saved in folder /mnt/ext1/seojin/temp/MOBL_aligned2
| INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM2-P1
# 2026-04-23 00:56:13.486 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] PECM2-P2
# 2026-04-23 00:56:13.721 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] PECM2-P3
# 2026-04-23 00:56:14.077 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM2-P4
# 2026-04-23 00:56:14.078 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM2-P5
# 2026-04-23 00:56:14.079 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-23 00:56:14.079 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-23 00:56:14.081 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-04-23 00:56:14.083 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-04-23 00:56:14.084 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_2
# 2026-04-23 00:56:14.086 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] PECM3
# 2026-04-23 00:56:14.088 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM3-P1
# 2026-04-23 00:56:14.088 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] PECM3-P2
# 2026-04-23 00:56:14.326 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] PECM3-P3
# 2026-04-23 00:56:14.552 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM3-P4
# 2026-04-23 00:56:14.553 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM3-P5
# 2026-04-23 00:56:14.554 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-23 00:56:14.554 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-23 00:56:14.556 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-04-23 00:56:14.558 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-04-23 00:56:14.560 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] LAT1
# 2026-04-23 00:56:14.561 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT1-P1
# 2026-04-23 00:56:14.561 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] LAT1-P2
# 2026-04-23 00:56:14.788 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] LAT1-P3
# 2026-04-23 00:56:15.018 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] LAT1-P4
# 2026-04-23 00:56:15.257 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] LAT1-P5
# 2026-04-23 00:56:15.483 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT1-P6
# 2026-04-23 00:56:15.484 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT1-P7
# 2026-04-23 00:56:15.485 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-23 00:56:15.485 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-23 00:56:15.487 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-04-23 00:56:15.490 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-04-23 00:56:15.492 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] LAT2
# 2026-04-23 00:56:15.493 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT2-P1
# 2026-04-23 00:56:15.494 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] LAT2-P2
# ...
# 2026-04-23 00:56:58.177 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 44 ; 1 percentage similarities; Best obj: 0.0
# 2026-04-23 00:56:58.207 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 45 ; 1 percentage similarities; Best obj: 0.0
# 2026-04-23 00:56:58.237 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 46 ; 1 percentage similarities; Best obj: 0.0
# 2026-04-23 00:56:58.265 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 47 ; 1 percentage similarities; Best obj: 0.0
# 2026-04-23 00:56:58.299 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 48 ; 1 percentage similarities; Best obj: 0.0
# 2026-04-23 00:56:58.328 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 49 ; 1 percentage similarities; Best obj: 0.0
# 2026-04-23 00:56:58.493 | INFO     | myoconverter.conversion_steps.O2MStep3:optMuscleForce:273 - Muscle : TMIN
# 2026-04-23 00:56:58.699 | ERROR    | myoconverter.conversion_steps.O2MStep3:optMuscleForce:314 - An error has been caught in function 'optMuscleForce', process 'MainProcess' (618912), thread 'MainThread' (138304704214080):
# Traceback (most recent call last):
#
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7dc9921fe340, file "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykern...
#            └ <function _run_code at 0x7dc99200de10>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7dc9921fe340, file "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykern...
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelap...
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7dc98f6c92d0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7dc9921249d0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7dc98f6cb370>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7dc98c109ae0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7dc9921249d0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7dc991544ee0>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7dc98c109ae0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7dc9915469e0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7dc9917d23b0>
#     └ <Handle <TaskStepMethWrapper object at 0x7dc98c10bf70>()>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle <TaskStepMethWrapper object at 0x7dc98c10bf70>()>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle <TaskStepMethWrapper object at 0x7dc98c10bf70>()>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle <TaskStepMethWrapper object at 0x7dc98c10bf70>()>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#                  │  │       └ {}
#                  │  └ ([<zmq.Frame(b'0264431c-736'...36B)>, <zmq.Frame(b'<IDS|MSG>')>, <zmq.Frame(b'bced5f26595b'...64B)>, <zmq.Frame(b'{"date":"20...
#                  └ functools.partial(<bound method Kernel.shell_main of <ipykernel.ipkernel.IPythonKernel object at 0x7dc98f538a30>>, None)
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#           │    │              │                └ None
#           │    │              └ [<zmq.Frame(b'0264431c-736'...36B)>, <zmq.Frame(b'<IDS|MSG>')>, <zmq.Frame(b'bced5f26595b'...64B)>, <zmq.Frame(b'{"date":"202...
#           │    └ <function Kernel.dispatch_shell at 0x7dc98f661480>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7dc98f538a30>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x7dc79d7dc5f0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2026, 4, 22, 15, 56, 7, 839000, tzinfo=tzutc()), 'msg_id': '023dcac2-acb8-42ea-b8fe-1bf...
#                                   │       └ [b'0264431c-7369-4d58-af12-a2a6d0078444']
#                                   └ <zmq.Socket(zmq.PAIR) at 0x7dc98c085d20>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7dc79d7dc660>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7dc98f699360>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7dc98c0939a0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': '8521befc-7803-44aa-b060-3e9f7c901af7'}
#                              └ ('############### Simple Arm 2 DoFs 6 Muscles ################ \nO2MPipeline(osim_file, geometry_folder, output_folder, **kwa...
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7dc9903563b0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7dc98c0939a0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x7dc79d7dff40>
#              └ <function _pseudo_sync_runner at 0x7dc990341cf0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7dc79d7dff40>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_618912/101032728.py'
#                        │    │             │        └ [<ast.Expr object at 0x7dc98c10a500>]
#                        │    │             └ <ast.Module object at 0x7dc7fc56e320>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7dc990356680>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7dc98c0939a0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7dc98c10a980, execution_count=5 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#              │    │        └ <code object <module> at 0x7dc991b612c0, file "/tmp/ipykernel_618912/101032728.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x7dc990356710>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7dc98c0939a0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7dc98c0939a0>
#          │         │    └ <property object at 0x7dc990344a90>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7dc98c0939a0>
#          └ <code object <module> at 0x7dc991b612c0, file "/tmp/ipykernel_618912/101032728.py", line 1>
#
#   File "/tmp/ipykernel_618912/101032728.py", line 2, in <module>
#     O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
#     │           │          │                │                └ {'convert_steps': [1, 2, 3], 'muscle_list': None, 'osim_data_overwrite': True, 'conversion': True, 'validation': True, 'speed...
#     │           │          │                └ '/mnt/ext1/seojin/temp/MOBL_aligned2'
#     │           │          └ '/mnt/sdb2/DeepProprioception/OpenSim/Geometry'
#     │           └ '/mnt/sdb2/DeepProprioception/OpenSim/MOBL_ARMS_41_pointAligned.osim'
#     └ <function O2MPipeline at 0x7dc98c0c25f0>
#
#   File "/home/seojin/myoconverter/myoconverter/O2MPipeline.py", line 64, in O2MPipeline
#     O2MSteps_inst.PipelineExecution()
#     │             └ <function O2MSteps.PipelineExecution at 0x7dc79d7d1360>
#     └ <myoconverter.conversion_steps.O2MSteps.O2MSteps object at 0x7dc98c0d3430>
#
#   File "/home/seojin/myoconverter/myoconverter/conversion_steps/O2MSteps.py", line 261, in PipelineExecution
#     mjcModel_Cvt3_path = musForceOpt.optMuscleForce()
#                          │           └ <function MuscleForceOpt.optMuscleForce at 0x7dc7e27952d0>
#                          └ <myoconverter.conversion_steps.O2MStep3.MuscleForceOpt object at 0x7dc5ee72b220>
#
# > File "/home/seojin/myoconverter/myoconverter/conversion_steps/O2MStep3.py", line 314, in optMuscleForce
#     opt_results, self.mjc_model = fmOptPSO_cust(cvt3_model_path, muscle, joints_uniq,\
#     │            │    │           │             │                │       └ []
#     │            │    │           │             │                └ 'TMIN'
#     │            │    │           │             └ '/mnt/ext1/seojin/temp/MOBL_aligned2/MOBL_ARMS_41_pointAligned_cvt3.xml'
#     │            │    │           └ <function fmOptPSO_cust at 0x7dc7e2794f70>
#     │            │    └ <mujoco._structs.MjModel object at 0x7dc6083f4c70>
#     │            └ <myoconverter.conversion_steps.O2MStep3.MuscleForceOpt object at 0x7dc5ee72b220>
#     └ {'cost_org': 0.1588089354909502, 'cost_opt': 2.4085363592440956e-08, 'res_opt': array([0.26576398, 1.7261807 , 1.05145916, 0....
#
#   File "/home/seojin/myoconverter/myoconverter/optimization/utils/UtilsForceOpt.py", line 144, in fmOptPSO_cust
#     shared_model = mujoco.MjModel.from_xml_path(mjc_model_path)
#                    │      │       │             └ '/mnt/ext1/seojin/temp/MOBL_aligned2/MOBL_ARMS_41_pointAligned_cvt3.xml'
#                    │      │       └ <staticmethod(<built-in method from_xml_path of PyCapsule object at 0x7dc8e2133a80>)>
#                    │      └ <class 'mujoco._structs.MjModel'>
#                    └ <module 'mujoco' from '/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/mujoco/__init__.py'>
#
# ValueError: Error: range[0]<range[1] required in muscle 'TMIN' (id = 6)
# Object name = TMIN, id = 6, line = 1620, column = -1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 ############### Simple Arm 2 DoFs 6 Muscles ################
# ----> 2 O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
#
# File ~/myoconverter/myoconverter/O2MPipeline.py:64, in O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
#      55 osim_data_overwrite = coordinate_kwargs(osim_file, output_folder, convert_steps,\
#      56                                osim_data_overwrite, conversion, validation, speedy)
#      58 O2MSteps_inst = O2MSteps(osim_file, geometry_folder, output_folder,\
#      59              convert_steps = convert_steps, muscle_list = muscle_list,\
#      60              osim_data_overwrite = osim_data_overwrite, convert = conversion,\
#      61              validation = validation, generate_pdf = generate_pdf, speedy = speedy,\
#      62              add_ground_geom = add_ground_geom, treat_as_normal_path_point = treat_as_normal_path_point)
# ---> 64 O2MSteps_inst.PipelineExecution()
#      66 logger.remove()
#
# File ~/myoconverter/myoconverter/conversion_steps/O2MSteps.py:261, in O2MSteps.PipelineExecution(self)
#     258 if self.convert:
#     259     # optimize muscle parameters and save optimized model as cvt3
#     260     logger.info("Started step 3 conversion - cvt3.")
# --> 261     mjcModel_Cvt3_path = musForceOpt.optMuscleForce()
#     262     logger.info("Finished step 3 conversion - cvt3.")
#     263 else:
#
# File ~/myoconverter/myoconverter/conversion_steps/O2MStep3.py:314, in MuscleForceOpt.optMuscleForce(self)
#     309     optParam_lb = [0.01, 1,\
#     310                    0.01, 0.5]  # lower bounds of lmin, lmax, fpmax, fmax
#     311     optParam_ub = [1, 1.99,\
#     312                    5, 2]  # upper bounds of lmin, lmax, fpmax, fmax
# --> 314     opt_results, self.mjc_model = fmOptPSO_cust(cvt3_model_path, muscle, joints_uniq,\
#     315                                            mjc_jnt_arr, act_arr, osimFP,\
#     316                                            optParam_lb, optParam_ub,\
#     317                                            cost_org)
#     319     muscle_para['opt_results'] = opt_results
#     321 else:  # if the error is smaller than threshold, then directly save the results
#
# TypeError: cannot unpack non-iterable NoneType object
