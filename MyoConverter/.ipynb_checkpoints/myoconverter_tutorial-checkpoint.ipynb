# %% [markdown]
# # References
# - https://github.com/MyoHub/myoconverter

# %% [markdown]
# # Common Libraries

# %%
import os, sys

# myoconverter
if 'CONDA_PREFIX' not in os.environ:
    os.environ['CONDA_PREFIX'] = sys.prefix
myoconverter_path = "/home/seojin/myoconverter"
sys.path.append(myoconverter_path)
from myoconverter.O2MPipeline import O2MPipeline

# %% [markdown]
# # Paths

# %%
osim_dir_path = "/home/seojin/myoconverter/models/osim/Arm26"

osim_file = os.path.join(osim_dir_path, "arm26.osim")
geometry_folder = os.path.join(osim_dir_path, "Geometry")
output_folder = "/mnt/ext1/seojin/temp/arm26"

# %% [markdown]
# # Params

# %%
# define pipeline configurations
kwargs = {}  # define kwargs inputs
kwargs['convert_steps'] = [1, 2, 3]    # All three steps selected
kwargs['muscle_list'] = None           # No specific muscle selected, optimize all of them
kwargs['osim_data_overwrite'] = True   # Overwrite the Osim model state files
kwargs['conversion'] = True            # Yes, perform 'Cvt#' process
kwargs['validation'] = True            # Yes, perform 'Vlt#' process
kwargs['speedy'] = False               # Do not reduce the checking notes to increase speed
kwargs['generate_pdf'] = True          # Do not generate validation pdf report
kwargs['add_ground_geom'] = True       # Add ground to the model
kwargs['treat_as_normal_path_point'] = False    # Using constraints to represent moving and conditional path points

# %% [markdown]
# # Execution

# %%
############### Simple Arm 2 DoFs 6 Muscles ################ 
O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
# Out:
# 2026-04-21 16:28:38.298 | INFO     | myoconverter.O2MPipeline:O2MPipeline:52 - Start the conversion pipeline for : arm26
# 2026-04-21 16:28:38.300 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:75 - Coordinate the input configurations, remove conflicts.
# 2026-04-21 16:28:38.300 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:86 -    Checking configurations for step 2 conversion.
# 2026-04-21 16:28:38.301 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:101 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-04-21 16:28:38.302 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:103 -        All good now.
# 2026-04-21 16:28:38.303 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:119 -    Checking configurations for step 3 conversion.
# 2026-04-21 16:28:38.304 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:134 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-04-21 16:28:38.304 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:136 -        All good now.
# 2026-04-21 16:28:38.305 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:84 - Given OpenSim model file: /home/seojin/myoconverter/models/osim/Arm26/arm26.osim
# 2026-04-21 16:28:38.306 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:85 - Reading mesh files from folder /home/seojin/myoconverter/models/osim/Arm26/Geometry
# 2026-04-21 16:28:38.306 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:86 - Converted model will be saved in folder /mnt/ext1/seojin/temp/arm26
# 2026-04-21 16:28:38.308 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:124 - Started step 1 conversion - cvt1.
# 2026-04-21 16:28:38.720 | INFO     | myoconverter.xml.converter:convert:40 - Commencing the conversion procedure!
# 2026-04-21 16:28:38.721 | INFO     | myoconverter.xml.converter:_parse_ground:138 - Parsing the ground
# 2026-04-21 16:28:38.721 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Ground] ground
# 2026-04-21 16:28:38.722 | INFO     | myoconverter.xml.converter:_parse_constraints:147 - Starting to parse constraints
# 2026-04-21 16:28:38.723 | INFO     | myoconverter.xml.converter:_parse_bodies_and_joints:80 - Starting to parse bodies, wrapping objects, and joints
# 2026-04-21 16:28:38.724 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] base
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# 2026-04-21 16:28:40.295 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] TRIlongglen
# 2026-04-21 16:28:40.296 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: WeldJoint] offset
# 2026-04-21 16:28:40.297 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] r_humerus
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# 2026-04-21 16:28:40.347 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] TRIlonghh
# 2026-04-21 16:28:40.348 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] BIClonghh
# 2026-04-21 16:28:40.349 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] TRI
# 2026-04-21 16:28:40.349 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] r_shoulder
# 2026-04-21 16:28:40.351 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] r_ulna_radius_hand
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# 2026-04-21 16:28:41.006 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] r_elbow
# 2026-04-21 16:28:41.008 | INFO     | myoconverter.xml.converter:_parse_forces:156 - Starting to parse forces, including path points and wrap paths
# 2026-04-21 16:28:41.008 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Thelen2003Muscle] TRIlong
# 2026-04-21 16:28:41.009 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P1
# 2026-04-21 16:28:41.010 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P2
# 2026-04-21 16:28:41.010 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P3
# 2026-04-21 16:28:41.011 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P4
# 2026-04-21 16:28:41.011 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P5
# 2026-04-21 16:28:41.012 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-21 16:28:41.012 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] TRIlong-wrap-cylinder1
# 2026-04-21 16:28:41.015 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] TRIlong-wrap-ellipsoid
# 2026-04-21 16:28:41.017 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] TRIlong-wrap-cylinder2
# 2026-04-21 16:28:41.019 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Thelen2003Muscle] TRIlat
# 2026-04-21 16:28:41.020 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P1
# 2026-04-21 16:28:41.021 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P2
# 2026-04-21 16:28:41.022 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P3
# 2026-04-21 16:28:41.023 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P4
# 2026-04-21 16:28:41.023 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P5
# 2026-04-21 16:28:41.024 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-21 16:28:41.025 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-21 16:28:41.027 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Thelen2003Muscle] TRImed
# 2026-04-21 16:28:41.028 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P1
# 2026-04-21 16:28:41.029 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P2
# 2026-04-21 16:28:41.029 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P3
# 2026-04-21 16:28:41.030 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P4
# 2026-04-21 16:28:41.031 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P5
# 2026-04-21 16:28:41.031 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-21 16:28:41.032 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-21 16:28:41.034 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Thelen2003Muscle] BIClong
# 2026-04-21 16:28:41.035 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P1
# 2026-04-21 16:28:41.035 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P2
# 2026-04-21 16:28:41.036 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P3
# 2026-04-21 16:28:41.036 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P4
# 2026-04-21 16:28:41.037 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P5
# 2026-04-21 16:28:41.038 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P6
# 2026-04-21 16:28:41.038 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P7
# 2026-04-21 16:28:41.039 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P8
# 2026-04-21 16:28:41.041 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P9
# 2026-04-21 16:28:41.041 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-21 16:28:41.042 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-21 16:28:41.043 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Thelen2003Muscle] BICshort
# 2026-04-21 16:28:41.044 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P1
# 2026-04-21 16:28:41.045 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P2
# 2026-04-21 16:28:41.046 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P3
# 2026-04-21 16:28:41.046 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P4
# 2026-04-21 16:28:41.047 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P5
# 2026-04-21 16:28:41.047 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P6
# 2026-04-21 16:28:41.048 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-21 16:28:41.048 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Thelen2003Muscle] BRA
# 2026-04-21 16:28:41.049 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BRA-P1
# 2026-04-21 16:28:41.050 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BRA-P2
# 2026-04-21 16:28:41.051 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-21 16:28:41.052 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-21 16:28:41.053 | INFO     | myoconverter.xml.converter:_parse_markers:165 - Starting to parse markers
# 2026-04-21 16:28:41.054 | INFO     | myoconverter.xml.parsers:parse:59 - [MarkerParser: Marker] r_acromion
# 2026-04-21 16:28:41.054 | INFO     | myoconverter.xml.parsers:parse:59 - [MarkerParser: Marker] r_humerus_epicondyle
# 2026-04-21 16:28:41.055 | INFO     | myoconverter.xml.parsers:parse:59 - [MarkerParser: Marker] r_radius_styloid
# 2026-04-21 16:28:41.055 | INFO     | myoconverter.xml.converter:_set_keyframe:176 - Setting the default keyframe
# 2026-04-21 16:28:41.056 | INFO     | myoconverter.xml.converter:convert:65 - Writing the converted model into /mnt/ext1/seojin/temp/arm26/arm26_cvt1.xml
# 2026-04-21 16:28:41.057 | INFO     | myoconverter.xml.converter:convert:68 - All good, conversion procedure is finished
# 2026-04-21 16:28:41.058 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:126 - Finished step 1 conversion - cvt1.
# 2026-04-21 16:28:41.058 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:132 - Started step 1 validation - val1.
# 2026-04-21 16:28:41.059 | INFO     | myoconverter.conversion_steps.O2MStep1:vlt1_forwardKinematicsValidation:123 - Extract marker names (as endpoints) from osim model
# 2026-04-21 16:28:41.067 | INFO     | myoconverter.conversion_steps.O2MStep1:vlt1_forwardKinematicsValidation:145 - Get the endpoint locations by meshing the joint angles within the range limits
# [info] Loaded model arm26 from file /home/seojin/myoconverter/models/osim/Arm26/arm26.osim
# [info] Loaded model arm26 from file /home/seojin/myoconverter/models/osim/Arm26/arm26.osim
# 2026-04-21 16:28:41.389 | INFO     | myoconverter.conversion_steps.O2MStep1:vlt1_forwardKinematicsValidation:152 - Check if the joint motion ranges are the same between Osim and Mjc models
# 2026-04-21 16:28:41.390 | INFO     | myoconverter.conversion_steps.O2MStep1:vlt1_forwardKinematicsValidation:172 - Finished with joint operation range check. Saved Results
# 2026-04-21 16:28:41.390 | INFO     | myoconverter.conversion_steps.O2MStep1:endPointsPlot:180 - Plot each endpoint's location errors in x, y, z.
# 2026-04-21 16:28:41.391 | INFO     | myoconverter.conversion_steps.O2MStep1:endPointsPlot:192 - Endpoint : r_acromion
# 2026-04-21 16:28:41.520 | INFO     | myoconverter.conversion_steps.O2MStep1:endPointsPlot:192 - Endpoint : r_humerus_epicondyle
# 2026-04-21 16:28:41.620 | INFO     | myoconverter.conversion_steps.O2MStep1:endPointsPlot:192 - Endpoint : r_radius_styloid
# 2026-04-21 16:28:41.722 | INFO     | myoconverter.conversion_steps.O2MStep1:endPointsPlot:256 - Generate overall error Bar plot
# 2026-04-21 16:28:41.770 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:142 - Finished step 1 validation - val1.
# 2026-04-21 16:28:41.771 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:175 - xxx_cvt2 model does not exist, start from xxx_cvt1
