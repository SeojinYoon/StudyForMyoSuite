# %% [markdown]
# # References
# - https://github.com/MyoHub/myoconverter

# %% [markdown]
# # Common Libraries

# %%
import os, sys

# myoconverter
if 'CONDA_PREFIX' not in os.environ:
    os.environ['CONDA_PREFIX'] = sys.prefix
myoconverter_path = "/home/seojin/myoconverter"
sys.path.append(myoconverter_path)
from myoconverter.O2MPipeline import O2MPipeline
import xml.etree.ElementTree as ET
from pathlib import Path

# %% [markdown]
# # Custom Libraries

# %%
def extract_muscle_names(osim_file_path, tag = "Millard2012EquilibriumMuscle"):
    tree = ET.parse(osim_file_path)
    root = tree.getroot()

    muscle_names = []
    for muscle in root.iter(tag):
        name = muscle.get('name')
        if name:
            muscle_names.append(name)

    return muscle_names

# %% [markdown]
# # Paths

# %%
osim_dir_path = "/mnt/sdb2/DeepProprioception/Projects/DP01_mri/Opensim/Model"
osim_file_path = os.path.join(osim_dir_path, "scaled_model.osim")
geometry_dir_path = os.path.join(osim_dir_path, "Geometry")
model_name = Path(osim_file_path).stem
output_dir_path = f"/mnt/ext1/seojin/temp/{model_name}"
print(output_dir_path)
os.makedirs(output_dir_path, exist_ok = True)
os.system(f"rm -r {output_dir_path}/*")
# Out:
# /mnt/ext1/seojin/temp/MOBL_ARMS_41_pointAligned
# 0

# %%
osim_model_path = Path(osim_file_path)
parser = ET.XMLParser(target=ET.TreeBuilder(insert_comments=True))
tree = ET.parse(osim_model_path, parser)
root = tree.getroot()
coords = root.findall(".//Coordinate")

unlock_coords = ["elv_angle", "shoulder_elv", "shoulder_rot", "elbow_flexion", "pro_sup", "deviation", "flexion"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in unlock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "false"

lock_coords = ["r_x", "r_y", "r_z", "t_x", "t_y", "t_z"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in lock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "true"

tree.write(osim_model_path, xml_declaration=True, encoding='UTF-8')

# %% [markdown]
# # Params

# %%
# define pipeline configurations
kwargs = {}  # define kwargs inputs
kwargs['convert_steps'] = [1,2,3]    # All three steps selected
muscle_list = extract_muscle_names(osim_file_path)
#muscle_list.remove("TMIN")
#muscle_list.remove("EDCM")
kwargs['muscle_list'] = muscle_list           # No specific muscle selected, optimize all of them

kwargs['osim_data_overwrite'] = True   # Overwrite the Osim model state files
kwargs['conversion'] = True            # Yes, perform 'Cvt#' process
kwargs['validation'] = True            # Yes, perform 'Vlt#' process
kwargs['speedy'] = False               # Do not reduce the checking notes to increase speed
kwargs['generate_pdf'] = True          # Do not generate validation pdf report
kwargs['add_ground_geom'] = False       # Add ground to the model
kwargs['treat_as_normal_path_point'] = False    # Using constraints to represent moving and conditional path points

# %% [markdown]
# # Execution

# %%
# %%capture pipeline_output

O2MPipeline(osim_file_path, geometry_dir_path, output_dir_path, **kwargs)
# Out:
# 2026-04-23 22:53:50.478 | INFO     | myoconverter.O2MPipeline:O2MPipeline:52 - Start the conversion pipeline for : MOBL_ARMS_41_pointAligned
# 2026-04-23 22:53:50.479 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:75 - Coordinate the input configurations, remove conflicts.
# 2026-04-23 22:53:50.480 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:86 -    Checking configurations for step 2 conversion.
# 2026-04-23 22:53:50.481 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:101 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-04-23 22:53:50.482 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:103 -        All good now.
# 2026-04-23 22:53:50.483 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:119 -    Checking configurations for step 3 conversion.
# 2026-04-23 22:53:50.483 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:134 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-04-23 22:53:50.484 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:136 -        All good now.
# 2026-04-23 22:53:50.485 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:84 - Given OpenSim model file: /mnt/sdb2/DeepProprioception/OpenSim/MOBL_ARMS_41_pointAligned.osim
# 2026-04-23 22:53:50.486 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:85 - Reading mesh files from folder /mnt/sdb2/DeepProprioception/OpenSim/Geometry
# 2026-04-23 22:53:50.486 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:86 - Converted model will be saved in folder /mnt/ext1/seojin/temp/MOBL_ARMS_41_pointAligned
# 2026-04-23 22:53:50.487 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:124 - Started step 1 conversion - cvt1.
# 2026-04-23 22:53:50.949 | INFO     | myoconverter.xml.converter:convert:40 - Commencing the conversion procedure!
# 2026-04-23 22:53:50.949 | INFO     | myoconverter.xml.converter:_parse_ground:138 - Parsing the ground
# 2026-04-23 22:53:50.950 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Ground] ground
# 2026-04-23 22:53:50.951 | INFO     | myoconverter.xml.converter:_parse_constraints:147 - Starting to parse constraints
# 2026-04-23 22:53:50.951 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r2_con
# 2026-04-23 22:53:51.044 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r3_con
# 2026-04-23 22:53:51.127 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r2_con
# 2026-04-23 22:53:51.206 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r3_con
# 2026-04-23 22:53:51.286 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r1_con
# 2026-04-23 22:53:51.361 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r2_con
# 2026-04-23 22:53:51.441 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r3_con
# 2026-04-23 22:53:51.516 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r1_con
# 2026-04-23 22:53:51.589 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r2_con
# 2026-04-23 22:53:51.667 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r3_con
# 2026-04-23 22:53:51.743 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] shoulder1_r2_con
# 2026-04-23 22:53:51.812 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r1_con
# 2026-04-23 22:53:51.890 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r3_con
# 2026-04-23 22:53:51.965 | INFO     | myoconverter.xml.converter:_parse_bodies_and_joints:80 - Starting to parse bodies, wrapping objects, and joints
# 2026-04-23 22:53:51.966 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] thorax
# 2026-04-23 22:53:52.355 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Thorax
# 2026-04-23 22:53:52.356 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] groundthorax
# 2026-04-23 22:53:52.358 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavicle
# 2026-04-23 22:53:52.366 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] sternoclavicular
# 2026-04-23 22:53:52.367 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body
| INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] BIClong-P9
# 2026-04-23 22:53:58.632 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P10
# 2026-04-23 22:53:58.633 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-23 22:53:58.634 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-23 22:53:58.641 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-04-23 22:53:58.643 | WARNING  | myoconverter.xml.path_wraps.PathWrapSet:parse:49 - One or multiple sites in tendon BIClong_tendon are dynamically moving, and hence there may be missing wrapping sites. You should check the converted xml file yourself, and possibly add wrapping sites where needed (or modify the ranges of corresponding PathWraps in the OpenSim model).
# 2026-04-23 22:53:58.644 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] BICshort
# 2026-04-23 22:53:58.645 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P1
# 2026-04-23 22:53:58.646 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P2
# 2026-04-23 22:53:58.646 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P3
# 2026-04-23 22:53:58.647 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P4
# 2026-04-23 22:53:58.648 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P5
# 2026-04-23 22:53:58.648 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] BICshort-P6
# 2026-04-23 22:53:58.889 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P7
# 2026-04-23 22:53:58.890 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-23 22:53:58.891 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-23 22:53:58.895 | WARNING  | myoconverter.xml.path_wraps.PathWrapSet:parse:49 - One or multiple sites in tendon BICshort_tendon are dynamically moving, and hence there may be missing wrapping sites. You should check the converted xml file yourself, and possibly add wrapping sites where needed (or modify the ranges of corresponding PathWraps in the OpenSim model).
# 2026-04-23 22:53:58.896 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] BRA
# 2026-04-23 22:53:58.896 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BRA-P1
# 2026-04-23 22:53:58.897 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] BRA-P2
# 2026-04-23 22:53:59.117 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] BRA-P3
# 2026-04-23 22:53:59.342 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BRA-P4
# 2026-04-23 22:53:59.343 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-23 22:53:59.343 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] BRD
# 2026-04-23 22:53:59.344 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BRD-P1
# 2026-04-23 22:53:59.345 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BRD-P2
# 2026-04-23 22:53:59.345 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BRD-P3
# 2026-04-23 22:53:59.346 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-23 22:53:59.346 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-23 22:53:59.349 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] ECRL
# 2026-04-23 22:53:59.350 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] ECRL-P1
# ...
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:54:39.310 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:163 - Calculate moment arms from Osim model
# 2026-04-23 22:54:39.310 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: DELT1
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:55:04.600 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: DELT2
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:55:29.953 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: DELT3
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:55:54.958 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: SUPSP
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:56:20.157 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: INFSP
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:56:45.849 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: SUBSC
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:57:11.373 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: TMIN
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:57:37.112 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: TMAJ
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:58:02.565 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: PECM1
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:58:28.242 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: PECM2
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:58:53.755 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: PECM3
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:59:19.361 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: LAT1
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 22:59:44.995 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: LAT2
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:00:10.485 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: LAT3
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:00:35.977 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: CORB
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:01:01.463 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: TRIlong
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:02:11.567 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: TRIlat
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:02:12.127 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: TRImed
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:02:12.684 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: ANC
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:02:13.242 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: SUP
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:02:13.801 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: BIClong
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:04:59.384 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: BICshort
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:07:43.955 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: BRA
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:07:44.513 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: BRD
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-04-23 23:07:49.800 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: ECRL
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.

# %%
pipeline_output.show()
# Out:
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()

# %%
print(1)
# Out:
# 1
