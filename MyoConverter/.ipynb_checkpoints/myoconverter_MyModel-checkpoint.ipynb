# %% [markdown]
# # References
# - https://github.com/MyoHub/myoconverter

# %% [markdown]
# # Common Libraries

# %%
import os, sys

# myoconverter
if 'CONDA_PREFIX' not in os.environ:
    os.environ['CONDA_PREFIX'] = sys.prefix
myoconverter_path = "/home/seojin/myoconverter"
sys.path.append(myoconverter_path)
from myoconverter.O2MPipeline import O2MPipeline
import xml.etree.ElementTree as ET

# %% [markdown]
# # Custom Libraries

# %%
def extract_muscle_names(osim_file_path, tag = "Millard2012EquilibriumMuscle"):
    tree = ET.parse(osim_file_path)
    root = tree.getroot()

    muscle_names = []
    for muscle in root.iter(tag):
        name = muscle.get('name')
        if name:
            muscle_names.append(name)

    return muscle_names

# %% [markdown]
# # Paths

# %%
osim_dir_path = "/mnt/sdb2/DeepProprioception/Projects/DP01_mri/Opensim/Model"
osim_file = os.path.join(osim_dir_path, "scaled_model.osim")
geometry_folder = os.path.join(osim_dir_path, "Geometry")
output_folder = "/mnt/ext1/seojin/temp/mymodel"

# %% [markdown]
# # Params

# %%
# define pipeline configurations
kwargs = {}  # define kwargs inputs
kwargs['convert_steps'] = [1, 2, 3]    # All three steps selected
muscle_list = extract_muscle_names(osim_file)
muscle_list.remove("TMIN")
muscle_list.remove("EDCM")
kwargs['muscle_list'] = muscle_list           # No specific muscle selected, optimize all of them
kwargs['osim_data_overwrite'] = True   # Overwrite the Osim model state files
kwargs['conversion'] = True            # Yes, perform 'Cvt#' process
kwargs['validation'] = True            # Yes, perform 'Vlt#' process
kwargs['speedy'] = False               # Do not reduce the checking notes to increase speed
kwargs['generate_pdf'] = True          # Do not generate validation pdf report
kwargs['add_ground_geom'] = False       # Add ground to the model
kwargs['treat_as_normal_path_point'] = False    # Using constraints to represent moving and conditional path points

# %% [markdown]
# # Execution

# %%
############### Simple Arm 2 DoFs 6 Muscles ################ 
O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
# Out:
# 2026-04-22 23:45:12.066 | INFO     | myoconverter.O2MPipeline:O2MPipeline:52 - Start the conversion pipeline for : scaled_model
# 2026-04-22 23:45:12.067 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:75 - Coordinate the input configurations, remove conflicts.
# 2026-04-22 23:45:12.068 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:86 -    Checking configurations for step 2 conversion.
# 2026-04-22 23:45:12.069 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:101 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-04-22 23:45:12.069 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:103 -        All good now.
# 2026-04-22 23:45:12.070 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:119 -    Checking configurations for step 3 conversion.
# 2026-04-22 23:45:12.071 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:134 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-04-22 23:45:12.071 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:136 -        All good now.
# 2026-04-22 23:45:12.072 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:84 - Given OpenSim model file: /mnt/sdb2/DeepProprioception/Projects/DP01_mri/Opensim/Model/scaled_model.osim
# 2026-04-22 23:45:12.073 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:85 - Reading mesh files from folder /mnt/sdb2/DeepProprioception/Projects/DP01_mri/Opensim/Model/Geometry
| INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-04-22 23:45:15.428 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-04-22 23:45:15.430 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] PECM1
# 2026-04-22 23:45:15.430 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM1-P1
# 2026-04-22 23:45:15.431 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default
# 2026-04-22 23:45:15.431 | WARNING  | myoconverter.xml.path_points.utils:get_moving_path_point_dependency:100 - Encountered a MultiplierFunction with scale != 1 in path point default.This implementation has not been tested/validated, you better check it out yourself
# 2026-04-22 23:45:15.510 | WARNING  | myoconverter.xml.path_points.utils:get_moving_path_point_dependency:100 - Encountered a MultiplierFunction with scale != 1 in path point default.This implementation has not been tested/validated, you better check it out yourself
# 2026-04-22 23:45:15.593 | WARNING  | myoconverter.xml.path_points.utils:get_moving_path_point_dependency:100 - Encountered a MultiplierFunction with scale != 1 in path point default.This implementation has not been tested/validated, you better check it out yourself
# 2026-04-22 23:45:15.675 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_0
# 2026-04-22 23:45:15.906 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM1-P2
# 2026-04-22 23:45:15.906 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-22 23:45:15.907 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-22 23:45:15.908 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-04-22 23:45:15.910 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-04-22 23:45:15.912 | WARNING  | myoconverter.xml.path_wraps.PathWrapSet:parse:49 - One or multiple sites in tendon PECM1_tendon are dynamically moving, and hence there may be missing wrapping sites. You should check the converted xml file yourself, and possibly add wrapping sites where needed (or modify the ranges of corresponding PathWraps in the OpenSim model).
# 2026-04-22 23:45:15.913 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] PECM2
# 2026-04-22 23:45:15.913 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM2-P1
# 2026-04-22 23:45:15.914 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default
# 2026-04-22 23:45:15.915 | WARNING  | myoconverter.xml.path_points.utils:get_moving_path_point_dependency:100 - Encountered a MultiplierFunction with scale != 1 in path point default.This implementation has not been tested/validated, you better check it out yourself
# 2026-04-22 23:45:15.993 | WARNING  | myoconverter.xml.path_points.utils:get_moving_path_point_dependency:100 - Encountered a MultiplierFunction with scale != 1 in path point default.This implementation has not been tested/validated, you better check it out yourself
# 2026-04-22 23:45:16.077 | WARNING  | myoconverter.xml.path_points.utils:get_moving_path_point_dependency:100 - Encountered a MultiplierFunction with scale != 1 in path point default.This implementation has not been tested/validated, you better check it out yourself
# 2026-04-22 23:45:16.158 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_0
# 2026-04-22 23:45:16.388 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM2-P4
# 2026-04-22 23:45:16.388 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM2-P5
# 2026-04-22 23:45:16.389 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-04-22 23:45:16.390 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-04-22 23:45:16.392 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-04-22 23:45:16.393 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-04-22 23:45:16.395 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_2
# 2026-04-22 23:45:16.397 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] PECM3
# 2026-04-22 23:45:16.398 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM3-P1
# 2026-04-22 23:45:16.398 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default
# ...
# 2026-04-23 00:05:36.556 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 7 ; 12 percentage similarities; Best obj: 2.40482
# 2026-04-23 00:05:36.633 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 8 ; 24 percentage similarities; Best obj: 2.40482
# 2026-04-23 00:05:36.702 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 9 ; 32 percentage similarities; Best obj: 2.40482
# 2026-04-23 00:05:36.780 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:189 -         PSO iteration: 10 ; 49 percentage similarities; Best obj: 2.40482
# 2026-04-23 00:05:36.781 | INFO     | myoconverter.optimization.utils.UtilsForceOpt:fmOptPSO_cust:197 -         Break the optimization, since certain number of similar particles reached
# 2026-04-23 00:05:36.968 | INFO     | myoconverter.conversion_steps.O2MStep3:optMuscleForce:273 - Muscle : PECM1
# 2026-04-23 00:05:37.175 | ERROR    | myoconverter.conversion_steps.O2MStep3:optMuscleForce:314 - An error has been caught in function 'optMuscleForce', process 'MainProcess' (58914), thread 'MainThread' (124339946681408):
# Traceback (most recent call last):
#
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7116261fe340, file "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykern...
#            └ <function _run_code at 0x71162590de10>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7116261fe340, file "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykern...
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelap...
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7116230192d0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7116261249d0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x71162301b370>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x711620255ab0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7116261249d0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x71162473cee0>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x711620255ab0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x71162473e9e0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7116250ce3b0>
#     └ <Handle <TaskStepMethWrapper object at 0x7114a55f1a20>()>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle <TaskStepMethWrapper object at 0x7114a55f1a20>()>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle <TaskStepMethWrapper object at 0x7114a55f1a20>()>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle <TaskStepMethWrapper object at 0x7114a55f1a20>()>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#                  │  │       └ {}
#                  │  └ ([<zmq.Frame(b'ac718127-52e'...36B)>, <zmq.Frame(b'<IDS|MSG>')>, <zmq.Frame(b'7a10d4da22c6'...64B)>, <zmq.Frame(b'{"date":"20...
#                  └ functools.partial(<bound method Kernel.shell_main of <ipykernel.ipkernel.IPythonKernel object at 0x711622e94a90>>, None)
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#           │    │              │                └ None
#           │    │              └ [<zmq.Frame(b'ac718127-52e'...36B)>, <zmq.Frame(b'<IDS|MSG>')>, <zmq.Frame(b'7a10d4da22c6'...64B)>, <zmq.Frame(b'{"date":"202...
#           │    └ <function Kernel.dispatch_shell at 0x711622fb1480>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x711622e94a90>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x7114641afed0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2026, 4, 22, 14, 45, 11, 800000, tzinfo=tzutc()), 'msg_id': 'baba0e7b-7760-4490-acbb-59...
#                                   │       └ [b'ac718127-52e1-4a7b-9871-85483335d9c6']
#                                   └ <zmq.Socket(zmq.PAIR) at 0x7116201d5cb0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7114641afd80>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x711622fe9360>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7116201e38b0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': '8521befc-7803-44aa-b060-3e9f7c901af7'}
#                              └ ('############### Simple Arm 2 DoFs 6 Muscles ################ \nO2MPipeline(osim_file, geometry_folder, output_folder, **kwa...
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x711623ca63b0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7116201e38b0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x7114641afd10>
#              └ <function _pseudo_sync_runner at 0x711623c91cf0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7114641afd10>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_58914/101032728.py'
#                        │    │             │        └ [<ast.Expr object at 0x711464187a30>]
#                        │    │             └ <ast.Module object at 0x711464187a90>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x711623ca6680>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7116201e38b0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 711464187ca0, execution_count=5 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#              │    │        └ <code object <module> at 0x71162512d2c0, file "/tmp/ipykernel_58914/101032728.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x711623ca6710>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7116201e38b0>
#   File "/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7116201e38b0>
#          │         │    └ <property object at 0x711623c94c70>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7116201e38b0>
#          └ <code object <module> at 0x71162512d2c0, file "/tmp/ipykernel_58914/101032728.py", line 1>
#
#   File "/tmp/ipykernel_58914/101032728.py", line 2, in <module>
#     O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
#     │           │          │                │                └ {'convert_steps': [1, 2, 3], 'muscle_list': ['DELT1', 'DELT2', 'DELT3', 'SUPSP', 'INFSP', 'SUBSC', 'TMAJ', 'PECM1', 'PECM2', ...
#     │           │          │                └ '/mnt/ext1/seojin/temp/mymodel'
#     │           │          └ '/mnt/sdb2/DeepProprioception/Projects/DP01_mri/Opensim/Model/Geometry'
#     │           └ '/mnt/sdb2/DeepProprioception/Projects/DP01_mri/Opensim/Model/scaled_model.osim'
#     └ <function O2MPipeline at 0x711620212680>
#
#   File "/home/seojin/myoconverter/myoconverter/O2MPipeline.py", line 64, in O2MPipeline
#     O2MSteps_inst.PipelineExecution()
#     │             └ <function O2MSteps.PipelineExecution at 0x7114641a12d0>
#     └ <myoconverter.conversion_steps.O2MSteps.O2MSteps object at 0x711464187160>
#
#   File "/home/seojin/myoconverter/myoconverter/conversion_steps/O2MSteps.py", line 261, in PipelineExecution
#     mjcModel_Cvt3_path = musForceOpt.optMuscleForce()
#                          │           └ <function MuscleForceOpt.optMuscleForce at 0x7114a4b69240>
#                          └ <myoconverter.conversion_steps.O2MStep3.MuscleForceOpt object at 0x7112c61b0310>
#
# > File "/home/seojin/myoconverter/myoconverter/conversion_steps/O2MStep3.py", line 314, in optMuscleForce
#     opt_results, self.mjc_model = fmOptPSO_cust(cvt3_model_path, muscle, joints_uniq,\
#     │            │    │           │             │                │       └ ['elv_angle', 'shoulder_elv', 'shoulder_rot']
#     │            │    │           │             │                └ 'PECM1'
#     │            │    │           │             └ '/mnt/ext1/seojin/temp/mymodel/scaled_model_cvt3.xml'
#     │            │    │           └ <function fmOptPSO_cust at 0x7114a4b68ee0>
#     │            │    └ <mujoco._structs.MjModel object at 0x7112f9d8cc30>
#     │            └ <myoconverter.conversion_steps.O2MStep3.MuscleForceOpt object at 0x7112c61b0310>
#     └ {'cost_org': 2.938671663716818, 'cost_opt': 2.4048235549886052, 'res_opt': array([1.        , 1.        , 2.31511384, 2.     ...
#
#   File "/home/seojin/myoconverter/myoconverter/optimization/utils/UtilsForceOpt.py", line 144, in fmOptPSO_cust
#     shared_model = mujoco.MjModel.from_xml_path(mjc_model_path)
#                    │      │       │             └ '/mnt/ext1/seojin/temp/mymodel/scaled_model_cvt3.xml'
#                    │      │       └ <staticmethod(<built-in method from_xml_path of PyCapsule object at 0x71158250fd50>)>
#                    │      └ <class 'mujoco._structs.MjModel'>
#                    └ <module 'mujoco' from '/home/seojin/miniforge3/envs/myoconverter/lib/python3.10/site-packages/mujoco/__init__.py'>
#
# ValueError: Error: range[0]<range[1] required in muscle 'TMAJ' (id = 7)
# Object name = TMAJ, id = 7, line = 1648, column = -1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 ############### Simple Arm 2 DoFs 6 Muscles ################
# ----> 2 O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
#
# File ~/myoconverter/myoconverter/O2MPipeline.py:64, in O2MPipeline(osim_file, geometry_folder, output_folder, **kwargs)
#      55 osim_data_overwrite = coordinate_kwargs(osim_file, output_folder, convert_steps,\
#      56                                osim_data_overwrite, conversion, validation, speedy)
#      58 O2MSteps_inst = O2MSteps(osim_file, geometry_folder, output_folder,\
#      59              convert_steps = convert_steps, muscle_list = muscle_list,\
#      60              osim_data_overwrite = osim_data_overwrite, convert = conversion,\
#      61              validation = validation, generate_pdf = generate_pdf, speedy = speedy,\
#      62              add_ground_geom = add_ground_geom, treat_as_normal_path_point = treat_as_normal_path_point)
# ---> 64 O2MSteps_inst.PipelineExecution()
#      66 logger.remove()
#
# File ~/myoconverter/myoconverter/conversion_steps/O2MSteps.py:261, in O2MSteps.PipelineExecution(self)
#     258 if self.convert:
#     259     # optimize muscle parameters and save optimized model as cvt3
#     260     logger.info("Started step 3 conversion - cvt3.")
# --> 261     mjcModel_Cvt3_path = musForceOpt.optMuscleForce()
#     262     logger.info("Finished step 3 conversion - cvt3.")
#     263 else:
#
# File ~/myoconverter/myoconverter/conversion_steps/O2MStep3.py:314, in MuscleForceOpt.optMuscleForce(self)
#     309     optParam_lb = [0.01, 1,\
#     310                    0.01, 0.5]  # lower bounds of lmin, lmax, fpmax, fmax
#     311     optParam_ub = [1, 1.99,\
#     312                    5, 2]  # upper bounds of lmin, lmax, fpmax, fmax
# --> 314     opt_results, self.mjc_model = fmOptPSO_cust(cvt3_model_path, muscle, joints_uniq,\
#     315                                            mjc_jnt_arr, act_arr, osimFP,\
#     316                                            optParam_lb, optParam_ub,\
#     317                                            cost_org)
#     319     muscle_para['opt_results'] = opt_results
#     321 else:  # if the error is smaller than threshold, then directly save the results
#
# TypeError: cannot unpack non-iterable NoneType object
