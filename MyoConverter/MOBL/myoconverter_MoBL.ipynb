# %% [markdown]
# # References
# - https://github.com/MyoHub/myoconverter

# %% [markdown]
# # Common Libraries

# %%
import os, sys

# myoconverter
if 'CONDA_PREFIX' not in os.environ:
    os.environ['CONDA_PREFIX'] = sys.prefix
myoconverter_path = "/home/seojin/biomechanics_tools/myoconverter"
sys.path.append(myoconverter_path)
from myoconverter.O2MPipeline import O2MPipeline
import xml.etree.ElementTree as ET
from pathlib import Path

# %%
sys.path.append("/home/seojin/Seojin_commonTool/Module/")

from sj_opensim import extract_muscle_names

# %% [markdown]
# # Paths

# %%
osim_dir_path = "/mnt/sdb2/DeepProprioception/OpenSim"
osim_file_path = os.path.join(osim_dir_path, "MOBL_ARMS_41.osim")
muscle_names = extract_muscle_names(osim_file_path)
geometry_dir_path = os.path.join(osim_dir_path, "Geometry")
output_dir_path = f"/mnt/ext1/seojin/temp/{Path(osim_file_path).stem}"
print(output_dir_path)

if os.path.exists(output_dir_path):
    os.system(f"rm -r {output_dir_path}")
os.makedirs(output_dir_path, exist_ok = True)

temp_model_path = os.path.join(output_dir_path, "temp.osim")
temp_geometry_path = f"{output_dir_path}/Geometry"
os.system(f"cp -r {geometry_dir_path} {temp_geometry_path}")
# Out:
# /mnt/ext1/seojin/temp/MOBL_ARMS_41
# 0

# %%
osim_model_path = Path(osim_file_path)
parser = ET.XMLParser(target=ET.TreeBuilder(insert_comments=True))
tree = ET.parse(osim_model_path, parser)
root = tree.getroot()
coords = root.findall(".//Coordinate")

unlock_coords = ["elv_angle", "shoulder_elv", "shoulder_rot", "elbow_flexion", "pro_sup", "deviation", "flexion"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in unlock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "false"

lock_coords = ["r_x", "r_y", "r_z", "t_x", "t_y", "t_z"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in lock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "true"

tree.write(temp_model_path, xml_declaration=True, encoding='UTF-8')
print(f"save: {temp_model_path}")
# Out:
# save: /mnt/ext1/seojin/temp/MOBL_ARMS_41/temp.osim

# %% [markdown]
# # Params

# %%
# define pipeline configurations
kwargs = {}  # define kwargs inputs
kwargs['convert_steps'] = [1,2,3]    # All three steps selected
kwargs['muscle_list'] = muscle_names           # No specific muscle selected, optimize all of them

kwargs['osim_data_overwrite'] = False   # Overwrite the Osim model state files
kwargs['conversion'] = True            # Yes, perform 'Cvt#' process
kwargs['validation'] = True            # Yes, perform 'Vlt#' process
kwargs['speedy'] = False               # Do not reduce the checking notes to increase speed
kwargs['generate_pdf'] = True          # Do not generate validation pdf report
kwargs['add_ground_geom'] = False       # Add ground to the model
kwargs['treat_as_normal_path_point'] = True    # Using constraints to represent moving and conditional path points

# %% [markdown]
# # Execution

# %%
# %%capture pipeline_output

O2MPipeline(temp_model_path, geometry_dir_path, output_dir_path, **kwargs)
# Out:
# 2026-05-24 21:53:41.978 | INFO     | myoconverter.O2MPipeline:O2MPipeline:52 - Start the conversion pipeline for : temp
# 2026-05-24 21:53:41.979 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:75 - Coordinate the input configurations, remove conflicts.
# 2026-05-24 21:53:41.980 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:86 -    Checking configurations for step 2 conversion.
# 2026-05-24 21:53:41.981 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:101 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-05-24 21:53:41.981 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:103 -        All good now.
# 2026-05-24 21:53:41.982 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:119 -    Checking configurations for step 3 conversion.
# 2026-05-24 21:53:41.983 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:134 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-05-24 21:53:41.984 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:136 -        All good now.
# 2026-05-24 21:53:41.985 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:84 - Given OpenSim model file: /mnt/ext1/seojin/temp/MOBL_ARMS_41/temp.osim
# 2026-05-24 21:53:41.986 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:85 - Reading mesh files from folder /mnt/sdb2/DeepProprioception/OpenSim/Geometry
# 2026-05-24 21:53:41.986 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:86 - Converted model will be saved in folder /mnt/ext1/seojin/temp/MOBL_ARMS_41
# 2026-05-24 21:53:41.987 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:124 - Started step 1 conversion - cvt1.
# 2026-05-24 21:53:42.385 | INFO     | myoconverter.xml.converter:convert:40 - Commencing the conversion procedure!
# 2026-05-24 21:53:42.386 | INFO     | myoconverter.xml.converter:_parse_ground:138 - Parsing the ground
# 2026-05-24 21:53:42.387 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Ground] ground
# 2026-05-24 21:53:42.387 | INFO     | myoconverter.xml.converter:_parse_constraints:147 - Starting to parse constraints
# 2026-05-24 21:53:42.388 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r2_con
# 2026-05-24 21:53:42.485 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r3_con
# 2026-05-24 21:53:42.570 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r2_con
# 2026-05-24 21:53:42.650 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r3_con
# 2026-05-24 21:53:42.734 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r1_con
# 2026-05-24 21:53:42.812 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r2_con
# 2026-05-24 21:53:42.893 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r3_con
# 2026-05-24 21:53:42.971 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r1_con
# 2026-05-24 21:53:43.044 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r2_con
# 2026-05-24 21:53:43.125 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r3_con
# 2026-05-24 21:53:43.203 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] shoulder1_r2_con
# 2026-05-24 21:53:43.274 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r1_con
# 2026-05-24 21:53:43.355 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r3_con
# 2026-05-24 21:53:43.432 | INFO     | myoconverter.xml.converter:_parse_bodies_and_joints:80 - Starting to parse bodies, wrapping objects, and joints
# 2026-05-24 21:53:43.433 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] thorax
# 2026-05-24 21:53:43.835 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Thorax
# 2026-05-24 21:53:43.836 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] groundthorax
# 2026-05-24 21:53:43.838 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavicle
# 2026-05-24 21:53:43.846 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] sternoclavicular
# 2026-05-24 21:53:43.847 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavphant
# 2026-05-24 21:53:43.848 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] unrotscap
# 2026-05-24 21:53:43.849 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] scapula
# 2026-05-24 21:53:43.863 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid]
| INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] default_0
# 2026-05-24 21:53:44.622 | INFO     | myoconverter.xml.path_points.ConditionalPathPoint:parse:55 - Treating ConditionalPathPoint default_0, as a normal PathPoint
# 2026-05-24 21:53:44.622 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_1
# 2026-05-24 21:53:44.626 | INFO     | myoconverter.xml.path_points.MovingPathPoint:parse:58 - Treating MovingPathPoint default_1, as a normal PathPoint
# 2026-05-24 21:53:44.627 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_2
# 2026-05-24 21:53:44.630 | INFO     | myoconverter.xml.path_points.MovingPathPoint:parse:58 - Treating MovingPathPoint default_2, as a normal PathPoint
# 2026-05-24 21:53:44.630 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT1-P4
# 2026-05-24 21:53:44.631 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT1-P5
# 2026-05-24 21:53:44.632 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.632 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.637 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-24 21:53:44.639 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-05-24 21:53:44.642 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] LAT2
# 2026-05-24 21:53:44.643 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT2-P1
# 2026-05-24 21:53:44.644 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] default
# 2026-05-24 21:53:44.645 | INFO     | myoconverter.xml.path_points.ConditionalPathPoint:parse:55 - Treating ConditionalPathPoint default, as a normal PathPoint
# 2026-05-24 21:53:44.645 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] default_0
# 2026-05-24 21:53:44.646 | INFO     | myoconverter.xml.path_points.ConditionalPathPoint:parse:55 - Treating ConditionalPathPoint default_0, as a normal PathPoint
# 2026-05-24 21:53:44.646 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_1
# 2026-05-24 21:53:44.650 | INFO     | myoconverter.xml.path_points.MovingPathPoint:parse:58 - Treating MovingPathPoint default_1, as a normal PathPoint
# 2026-05-24 21:53:44.650 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_2
# 2026-05-24 21:53:44.654 | INFO     | myoconverter.xml.path_points.MovingPathPoint:parse:58 - Treating MovingPathPoint default_2, as a normal PathPoint
# 2026-05-24 21:53:44.654 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT2-P4
# 2026-05-24 21:53:44.655 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT2-P5
# 2026-05-24 21:53:44.655 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.656 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.661 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-24 21:53:44.663 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-05-24 21:53:44.666 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] LAT3
# 2026-05-24 21:53:44.667 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT3-P1
# 2026-05-24 21:53:44.667 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] default
# 2026-05-24 21:53:44.668 | INFO     | myoconverter.xml.path_points.ConditionalPathPoint:parse:55 - Treating ConditionalPathPoint default, as a normal PathPoint
# 2026-05-24 21:53:44.668 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] default_0
# 2026-05-24 21:53:44.669 | INFO     | myoconverter.xml.path_points.ConditionalPathPoint:parse:55 - Treating ConditionalPathPoint default_0, as a normal PathPoint
# 2026-05-24 21:53:44.669 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_1
# 2026-05-24 21:53:44.672 | INFO     | myoconverter.xml.path_points.MovingPathPoint:parse:58 - Treating MovingPathPoint default_1, as a normal PathPoint
# 2026-05-24 21:53:44.673 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_2
# 2026-05-24 21:53:44.677 | INFO     | myoconverter.xml.path_points.MovingPathPoint:parse:58 - Treating MovingPathPoint default_2, as a normal PathPoint
# 2026-05-24 21:53:44.678 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT3-P4
# 2026-05-24 21:53:44.678 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] LAT3-P5
# 2026-05-24 21:53:44.679 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.679 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.684 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-24 21:53:44.687 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-05-24 21:53:44.690 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] CORB
# 2026-05-24 21:53:44.690 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] CORB-P1
# 2026-05-24 21:53:44.691 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] CORB-P2
# 2026-05-24 21:53:44.692 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] CORB-P3
# 2026-05-24 21:53:44.692 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.693 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.695 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-24 21:53:44.698 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] TRIlong
# 2026-05-24 21:53:44.698 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P1
# 2026-05-24 21:53:44.699 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P2
# 2026-05-24 21:53:44.699 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P3
# 2026-05-24 21:53:44.700 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P4
# 2026-05-24 21:53:44.700 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlong-P5
# 2026-05-24 21:53:44.701 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.702 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.706 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-24 21:53:44.709 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-05-24 21:53:44.711 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] TRIlat
# 2026-05-24 21:53:44.711 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P1
# 2026-05-24 21:53:44.712 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P2
# 2026-05-24 21:53:44.712 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P3
# 2026-05-24 21:53:44.713 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P4
# 2026-05-24 21:53:44.713 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRIlat-P5
# 2026-05-24 21:53:44.715 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.715 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.719 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] TRImed
# 2026-05-24 21:53:44.719 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P1
# 2026-05-24 21:53:44.720 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P2
# 2026-05-24 21:53:44.720 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P3
# 2026-05-24 21:53:44.721 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P4
# 2026-05-24 21:53:44.721 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TRImed-P5
# 2026-05-24 21:53:44.722 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.722 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.726 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] ANC
# 2026-05-24 21:53:44.726 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] ANC-P1
# 2026-05-24 21:53:44.727 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] ANC-P2
# 2026-05-24 21:53:44.727 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.728 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.730 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] SUP
# 2026-05-24 21:53:44.730 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUP-P1
# 2026-05-24 21:53:44.731 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUP-P2
# 2026-05-24 21:53:44.733 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUP-P3
# 2026-05-24 21:53:44.733 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.734 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.736 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] BIClong
# 2026-05-24 21:53:44.737 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P1
# 2026-05-24 21:53:44.738 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P2
# 2026-05-24 21:53:44.738 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P3
# 2026-05-24 21:53:44.739 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P4
# 2026-05-24 21:53:44.740 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P5
# 2026-05-24 21:53:44.740 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P6
# 2026-05-24 21:53:44.741 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P7
# 2026-05-24 21:53:44.741 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P8
# 2026-05-24 21:53:44.742 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default
# 2026-05-24 21:53:44.745 | INFO     | myoconverter.xml.path_points.MovingPathPoint:parse:58 - Treating MovingPathPoint default, as a normal PathPoint
# 2026-05-24 21:53:44.746 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BIClong-P11
# 2026-05-24 21:53:44.746 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-24 21:53:44.747 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-24 21:53:44.754 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-24 21:53:44.757 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] BICshort
# 2026-05-24 21:53:44.758 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P1
# 2026-05-24 21:53:44.758 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P2
# 2026-05-24 21:53:44.759 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] BICshort-P3
# ...
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:54:23.677 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:163 - Calculate moment arms from Osim model
# 2026-05-24 21:54:23.678 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: DELT1
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:54:49.525 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: DELT2
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:55:15.374 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: DELT3
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:55:41.220 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: SUPSP
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:56:07.099 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: INFSP
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:56:33.081 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: SUBSC
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:56:58.910 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: TMIN
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:57:25.307 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: TMAJ
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:57:52.437 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: PECM1
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:58:19.490 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: PECM2
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:58:47.398 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: PECM3
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:59:15.048 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: LAT1
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 21:59:42.959 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: LAT2
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 22:00:09.386 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: LAT3
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 22:00:35.721 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: CORB
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.
# 2026-05-24 22:01:02.025 | INFO     | myoconverter.optimization.model_states.OsimMuscleStates:getMomentArms:168 - Muscle: TRIlong
# [warning] Body 'thorax' is massless but nonzero inertia provided.
# [warning]  Inertia reset to zero. Otherwise provide nonzero mass.

# %%
pipeline_output.show()
# Out:
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
#
# Wrapping sidesite does not affect moment arm, not saving...
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()
# /home/seojin/biomechanics_tools/myoconverter/myoconverter/xml/bodies/utils.py:50: PyVistaFutureWarning: The default value of `algorithm` for the filter
# `PolyData.extract_surface` will change in the future. It currently defaults to
# `'dataset_surface'`, but will change to `None`. Explicitly set the `algorithm` keyword to
# silence this warning.
#   pymesh = pymesh.extract_surface().triangulate()

# %%
print(1)
# Out:
# 1

# %%
output_dir_path
# Out:
# '/mnt/ext1/seojin/temp/MOBL_ARMS_41'
