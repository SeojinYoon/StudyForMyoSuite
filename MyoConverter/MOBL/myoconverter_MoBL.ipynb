# %% [markdown]
# # References
# - https://github.com/MyoHub/myoconverter

# %% [markdown]
# # Common Libraries

# %%
import os, sys
from pathlib import Path
import xml.etree.ElementTree as ET

# myoconverter
if "CONDA_PREFIX" not in os.environ:
    os.environ["CONDA_PREFIX"] = sys.prefix
myoconverter_path = "/home/seojin/biomechanics_tools/myoconverter"
sys.path.append(myoconverter_path)
from myoconverter.O2MPipeline import O2MPipeline

# %%
sys.path.append("/home/seojin/Seojin_commonTool/Module/")
from sj_opensim import extract_muscle_names

# %% [markdown]
# # Paths

# %%
osim_dir_path = "/mnt/sdb2/DeepProprioception/OpenSim"
osim_file_path = os.path.join(osim_dir_path, "MOBL_ARMS_fixed_41.osim")
muscle_names = extract_muscle_names(osim_file_path)
geometry_dir_path = os.path.join(osim_dir_path, "Geometry")
output_dir_path = f"/mnt/ext1/seojin/temp/{Path(osim_file_path).stem}"
print(output_dir_path)

if os.path.exists(output_dir_path):
    os.system(f"rm -r {output_dir_path}")
os.makedirs(output_dir_path, exist_ok = True)

temp_model_path = os.path.join(output_dir_path, "temp.osim")
temp_geometry_path = f"{output_dir_path}/Geometry"
os.system(f"cp -r {geometry_dir_path} {temp_geometry_path}")
# Out:
# /mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41
# 0

# %%
osim_model_path = Path(osim_file_path)
parser = ET.XMLParser(target=ET.TreeBuilder(insert_comments=True))
tree = ET.parse(osim_model_path, parser)
root = tree.getroot()
coords = root.findall(".//Coordinate")

unlock_coords = ["elv_angle", "shoulder_elv", "shoulder_rot", "elbow_flexion", "pro_sup", "deviation", "flexion"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in unlock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "false"

lock_coords = ["r_x", "r_y", "r_z", "t_x", "t_y", "t_z"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in lock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "true"

tree.write(temp_model_path, xml_declaration=True, encoding='UTF-8')
print(f"save: {temp_model_path}")
# Out:
# save: /mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41/temp.osim

# %% [markdown]
# # Params

# %%
# define pipeline configurations
kwargs = {}  # define kwargs inputs
kwargs['convert_steps'] = [1,2,3]    # All three steps selected
kwargs['muscle_list'] = muscle_names           # No specific muscle selected, optimize all of them
kwargs['osim_data_overwrite'] = True   # Overwrite the Osim model state files
kwargs['conversion'] = True            # Yes, perform 'Cvt#' process
kwargs['validation'] = True            # Yes, perform 'Vlt#' process
kwargs['speedy'] = False               # Do not reduce the checking notes to increase speed
kwargs['generate_pdf'] = True          # Do not generate validation pdf report
kwargs['add_ground_geom'] = False       # Add ground to the model
kwargs['treat_as_normal_path_point'] = True # True    # Using constraints to represent moving and conditional path points

# %% [markdown]
# # Execution

# %%
# %%capture pipeline_output

O2MPipeline(temp_model_path, geometry_dir_path, output_dir_path, **kwargs)
# Out:
# 2026-05-25 15:13:30.303 | INFO     | myoconverter.O2MPipeline:O2MPipeline:52 - Start the conversion pipeline for : temp
# 2026-05-25 15:13:30.304 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:75 - Coordinate the input configurations, remove conflicts.
# 2026-05-25 15:13:30.304 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:86 -    Checking configurations for step 2 conversion.
# 2026-05-25 15:13:30.305 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:101 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-05-25 15:13:30.305 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:103 -        All good now.
# 2026-05-25 15:13:30.305 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:119 -    Checking configurations for step 3 conversion.
# 2026-05-25 15:13:30.306 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:134 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-05-25 15:13:30.306 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:136 -        All good now.
# 2026-05-25 15:13:30.307 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:84 - Given OpenSim model file: /mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41/temp.osim
# 2026-05-25 15:13:30.307 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:85 - Reading mesh files from folder /mnt/sdb2/DeepProprioception/OpenSim/Geometry
# 2026-05-25 15:13:30.308 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:86 - Converted model will be saved in folder /mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41
# 2026-05-25 15:13:30.308 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:124 - Started step 1 conversion - cvt1.
# 2026-05-25 15:13:30.685 | INFO     | myoconverter.xml.converter:convert:40 - Commencing the conversion procedure!
# 2026-05-25 15:13:30.685 | INFO     | myoconverter.xml.converter:_parse_ground:138 - Parsing the ground
# 2026-05-25 15:13:30.686 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Ground] ground
# 2026-05-25 15:13:31.088 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Thorax
# 2026-05-25 15:13:31.089 | INFO     | myoconverter.xml.converter:_parse_constraints:147 - Starting to parse constraints
# 2026-05-25 15:13:31.090 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r2_con
# 2026-05-25 15:13:31.199 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r3_con
# 2026-05-25 15:13:31.283 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r2_con
# 2026-05-25 15:13:31.364 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r3_con
# 2026-05-25 15:13:31.446 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r1_con
# 2026-05-25 15:13:31.524 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r2_con
# 2026-05-25 15:13:31.606 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r3_con
# 2026-05-25 15:13:31.684 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r1_con
# 2026-05-25 15:13:31.759 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r2_con
# 2026-05-25 15:13:31.839 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r3_con
# 2026-05-25 15:13:31.917 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] shoulder1_r2_con
# 2026-05-25 15:13:31.988 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r1_con
# 2026-05-25 15:13:32.070 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r3_con
# 2026-05-25 15:13:32.149 | INFO     | myoconverter.xml.converter:_parse_bodies_and_joints:80 - Starting to parse bodies, wrapping objects, and joints
# 2026-05-25 15:13:32.150 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavicle
# 2026-05-25 15:13:32.157 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] sternoclavicular
# 2026-05-25 15:13:32.159 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavphant
# 2026-05-25 15:13:32.159 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] unrotscap
# 2026-05-25 15:13:32.160 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] scapula
# 2026-05-25 15:13:32.173 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Deltoid2
# 2026-05-25 15:13:32.173 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] Delt3
# 2026-05-25 15:13:32.174 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] INFSP
# 2026-05-25 15:13:32.174 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] TMIN
# 2026-05-25 15:13:32.175 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] TRIlongglen
# 2026-05-25 15:13:32.175 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] acromioclavicular
# 2026-05-25 15:13:32.177 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] scapphant
# 2026-05-25 15:13:32.177 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] unrothum
# 2026-05-25 15:13:32.178 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] humphant
# 2026-05-25 15:13:32.179 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] shoulder0
# 2026-05-25 15:13:32.180 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] humphant1
# 2026-05-25 15:13:32.181 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] shoulder1
# 2026-05-25 15:13:32.182 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] humerus
# 2026-05-25 15:13:32.231 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] DELT1hh
# 2026-05-25 15:13:32.232 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] delt2hum
# 2026-05-25 15:13:32.232 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] delt3hum
# 2026-05-25 15:13:32.233 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] SUPSP
# 2026-05-25 15:13:32.233 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] INFSP_and_TMIN_hum_head
# 2026-05-25 15:13:32.234 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder