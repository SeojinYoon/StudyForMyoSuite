# %% [markdown]
# # References
# - https://github.com/MyoHub/myoconverter

# %% [markdown]
# # Common Libraries

# %%
import os, sys

# myoconverter
if 'CONDA_PREFIX' not in os.environ:
    os.environ['CONDA_PREFIX'] = sys.prefix
myoconverter_path = "/home/seojin/biomechanics_tools/myoconverter"
sys.path.append(myoconverter_path)
from myoconverter.O2MPipeline import O2MPipeline
import xml.etree.ElementTree as ET
from pathlib import Path

# %%
sys.path.append("/home/seojin/Seojin_commonTool/Module/")

from sj_opensim import extract_muscle_names

# %% [markdown]
# # Paths

# %%
osim_dir_path = "/mnt/sdb2/DeepProprioception/OpenSim"
osim_file_path = os.path.join(osim_dir_path, "MOBL_ARMS_41.osim")
muscle_names = extract_muscle_names(osim_file_path)
geometry_dir_path = os.path.join(osim_dir_path, "Geometry")
output_dir_path = f"/mnt/ext1/seojin/temp/{Path(osim_file_path).stem}"
print(output_dir_path)

if os.path.exists(output_dir_path):
    os.system(f"rm -r {output_dir_path}")
os.makedirs(output_dir_path, exist_ok = True)

temp_model_path = os.path.join(output_dir_path, "temp.osim")
temp_geometry_path = f"{output_dir_path}/Geometry"
os.system(f"cp -r {geometry_dir_path} {temp_geometry_path}")

# %%
osim_model_path = Path(osim_file_path)
parser = ET.XMLParser(target=ET.TreeBuilder(insert_comments=True))
tree = ET.parse(osim_model_path, parser)
root = tree.getroot()
coords = root.findall(".//Coordinate")

unlock_coords = ["elv_angle", "shoulder_elv", "shoulder_rot", "elbow_flexion", "pro_sup", "deviation", "flexion"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in unlock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "false"

lock_coords = ["r_x", "r_y", "r_z", "t_x", "t_y", "t_z"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in lock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "true"

tree.write(temp_model_path, xml_declaration=True, encoding='UTF-8')
print(f"save: {temp_model_path}")

# %% [markdown]
# # Params

# %%
# define pipeline configurations
kwargs = {}  # define kwargs inputs
kwargs['convert_steps'] = [1,2,3]    # All three steps selected
kwargs['muscle_list'] = muscle_names           # No specific muscle selected, optimize all of them

kwargs['osim_data_overwrite'] = False   # Overwrite the Osim model state files
kwargs['conversion'] = True            # Yes, perform 'Cvt#' process
kwargs['validation'] = True            # Yes, perform 'Vlt#' process
kwargs['speedy'] = True               # Do not reduce the checking notes to increase speed
kwargs['generate_pdf'] = True          # Do not generate validation pdf report
kwargs['add_ground_geom'] = False       # Add ground to the model
kwargs['treat_as_normal_path_point'] = True    # Using constraints to represent moving and conditional path points

# %% [markdown]
# # Execution

# %%
# %%capture pipeline_output

O2MPipeline(temp_model_path, geometry_dir_path, output_dir_path, **kwargs)
# Out:
# 2026-05-24 20:46:19.385 | INFO     | myoconverter.O2MPipeline:O2MPipeline:52 - Start the conversion pipeline for : temp
# 2026-05-24 20:46:19.386 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:75 - Coordinate the input configurations, remove conflicts.
# 2026-05-24 20:46:19.386 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:86 -    Checking configurations for step 2 conversion.
# 2026-05-24 20:46:19.387 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:101 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-05-24 20:46:19.388 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:103 -        All good now.
# 2026-05-24 20:46:19.389 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:119 -    Checking configurations for step 3 conversion.
# 2026-05-24 20:46:19.389 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:134 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-05-24 20:46:19.390 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:136 -        All good now.
# 2026-05-24 20:46:19.391 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:84 - Given OpenSim model file: /mnt/ext1/seojin/temp/MOBL_ARMS_41/temp.osim
# 2026-05-24 20:46:19.391 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:85 - Reading mesh files from folder /mnt/sdb2/DeepProprioception/OpenSim/Geometry
# 2026-05-24 20:46:19.392 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:86 - Converted model will be saved in folder /mnt/ext1/seojin/temp/MOBL_ARMS_41
# 2026-05-24 20:46:19.393 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:124 - Started step 1 conversion - cvt1.
# 2026-05-24 20:46:19.791 | INFO     | myoconverter.xml.converter:convert:40 - Commencing the conversion procedure!
# 2026-05-24 20:46:19.792 | INFO     | myoconverter.xml.converter:_parse_ground:138 - Parsing the ground
# 2026-05-24 20:46:19.793 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Ground] ground
# 2026-05-24 20:46:19.794 | INFO     | myoconverter.xml.converter:_parse_constraints:147 - Starting to parse constraints
# 2026-05-24 20:46:19.794 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r2_con
# 2026-05-24 20:46:19.890 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r3_con
# 2026-05-24 20:46:19.974 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r2_con
# 2026-05-24 20:46:20.052 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r3_con
# 2026-05-24 20:46:20.135 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r1_con
# 2026-05-24 20:46:20.211 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r2_con
# 2026-05-24 20:46:20.291 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r3_con
# 2026-05-24 20:46:20.369 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r1_con
# 2026-05-24 20:46:20.442 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r2_con
# 2026-05-24 20:46:20.523 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r3_con
# 2026-05-24 20:46:20.602 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] shoulder1_r2_con
# 2026-05-24 20:46:20.672 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r1_con
# 2026-05-24 20:46:20.752 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r3_con
# 2026-05-24 20:46:20.828 | INFO     | myoconverter.xml.converter:_parse_bodies_and_joints:80 - Starting to parse bodies, wrapping objects, and joints
# 2026-05-24 20:46:20.829 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] thorax
# 2026-05-24 20:46:21.231 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Thorax
# 2026-05-24 20:46:21.232 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] groundthorax
# 2026-05-24 20:46:21.235 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavicle
# 2026-05-24 20:46:21.242 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] sternoclavicular
# 2026-05-24 20:46:21.243 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavphant
# 2026-05-24 20:46:21.244 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] unrotscap
# 2026-05-24 20:46:21.245 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] scapula
# 2026-05-24 20:46:21.258 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Deltoid2
# 2026-05-24 20:46:21.259 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] Delt3
# 2026-05-24 20:46:21.260 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] INFSP
# 2026-05-24 20:46:21.261 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] TMIN
# 2026-05-24 20:46:21.261 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] TRIlongglen
# 2026-05-24 20:46:21.262 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint