# %% [markdown]
# # References
# - https://github.com/MyoHub/myoconverter

# %% [markdown]
# # Common Libraries

# %%
import os, sys
from pathlib import Path
import xml.etree.ElementTree as ET

# myoconverter
if "CONDA_PREFIX" not in os.environ:
    os.environ["CONDA_PREFIX"] = sys.prefix
myoconverter_path = "/home/seojin/biomechanics_tools/myoconverter"
sys.path.append(myoconverter_path)
from myoconverter.O2MPipeline import O2MPipeline

# %%
sys.path.append("/home/seojin/Seojin_commonTool/Module/")
from sj_opensim import extract_muscle_names

# %% [markdown]
# # Paths

# %%
osim_dir_path = "/mnt/sdb2/DeepProprioception/OpenSim"
osim_file_path = os.path.join(osim_dir_path, "MOBL_ARMS_fixed_41.osim")
muscle_names = extract_muscle_names(osim_file_path)
geometry_dir_path = os.path.join(osim_dir_path, "Geometry")
output_dir_path = f"/mnt/ext1/seojin/temp/{Path(osim_file_path).stem}"
print(output_dir_path)

if os.path.exists(output_dir_path):
    os.system(f"rm -r {output_dir_path}")
os.makedirs(output_dir_path, exist_ok = True)

temp_model_path = os.path.join(output_dir_path, "temp.osim")
temp_geometry_path = f"{output_dir_path}/Geometry"
os.system(f"cp -r {geometry_dir_path} {temp_geometry_path}")
# Out:
# /mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41
# 0

# %%
osim_model_path = Path(osim_file_path)
parser = ET.XMLParser(target=ET.TreeBuilder(insert_comments=True))
tree = ET.parse(osim_model_path, parser)
root = tree.getroot()
coords = root.findall(".//Coordinate")

unlock_coords = ["elv_angle", "shoulder_elv", "shoulder_rot", "elbow_flexion", "pro_sup", "deviation", "flexion"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in unlock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "false"

lock_coords = ["r_x", "r_y", "r_z", "t_x", "t_y", "t_z"]
for i in range(len(coords)):
    name = coords[i].get("name")
    if name in lock_coords:
        lock_element = coords[i].find("locked")
        lock_element.text = "true"

tree.write(temp_model_path, xml_declaration=True, encoding='UTF-8')
print(f"save: {temp_model_path}")
# Out:
# save: /mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41/temp.osim

# %% [markdown]
# # Params

# %%
# define pipeline configurations
kwargs = {}  # define kwargs inputs
kwargs['convert_steps'] = [1,2,3]    # All three steps selected
kwargs['muscle_list'] = muscle_names           # No specific muscle selected, optimize all of them
kwargs['osim_data_overwrite'] = True   # Overwrite the Osim model state files
kwargs['conversion'] = True            # Yes, perform 'Cvt#' process
kwargs['validation'] = True            # Yes, perform 'Vlt#' process
kwargs['speedy'] = False               # Do not reduce the checking notes to increase speed
kwargs['generate_pdf'] = True          # Do not generate validation pdf report
kwargs['add_ground_geom'] = False       # Add ground to the model
kwargs['treat_as_normal_path_point'] = False # True    # Using constraints to represent moving and conditional path points

# %% [markdown]
# # Execution

# %%
# %%capture pipeline_output

O2MPipeline(temp_model_path, geometry_dir_path, output_dir_path, **kwargs)
# Out:
# 2026-05-25 11:11:00.072 | INFO     | myoconverter.O2MPipeline:O2MPipeline:52 - Start the conversion pipeline for : temp
# 2026-05-25 11:11:00.073 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:75 - Coordinate the input configurations, remove conflicts.
# 2026-05-25 11:11:00.074 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:86 -    Checking configurations for step 2 conversion.
# 2026-05-25 11:11:00.075 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:101 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-05-25 11:11:00.075 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:103 -        All good now.
# 2026-05-25 11:11:00.076 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:119 -    Checking configurations for step 3 conversion.
# 2026-05-25 11:11:00.077 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:134 -        Configure of previous run does not exist, set osim_data_overwrite to TRUE.
# 2026-05-25 11:11:00.078 | INFO     | myoconverter.O2MPipeline:coordinate_kwargs:136 -        All good now.
# 2026-05-25 11:11:00.079 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:84 - Given OpenSim model file: /mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41/temp.osim
# 2026-05-25 11:11:00.079 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:85 - Reading mesh files from folder /mnt/sdb2/DeepProprioception/OpenSim/Geometry
# 2026-05-25 11:11:00.080 | INFO     | myoconverter.conversion_steps.O2MSteps:__init__:86 - Converted model will be saved in folder /mnt/ext1/seojin/temp/MOBL_ARMS_fixed_41
# 2026-05-25 11:11:00.081 | INFO     | myoconverter.conversion_steps.O2MSteps:PipelineExecution:124 - Started step 1 conversion - cvt1.
# 2026-05-25 11:11:00.462 | INFO     | myoconverter.xml.converter:convert:40 - Commencing the conversion procedure!
# 2026-05-25 11:11:00.463 | INFO     | myoconverter.xml.converter:_parse_ground:138 - Parsing the ground
# 2026-05-25 11:11:00.464 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Ground] ground
# 2026-05-25 11:11:00.851 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Thorax
# 2026-05-25 11:11:00.852 | INFO     | myoconverter.xml.converter:_parse_constraints:147 - Starting to parse constraints
# 2026-05-25 11:11:00.853 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r2_con
# 2026-05-25 11:11:00.972 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] sternoclavicular_r3_con
# 2026-05-25 11:11:01.054 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r2_con
# 2026-05-25 11:11:01.133 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrotscap_r3_con
# 2026-05-25 11:11:01.213 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r1_con
# 2026-05-25 11:11:01.289 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r2_con
# 2026-05-25 11:11:01.370 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] acromioclavicular_r3_con
# 2026-05-25 11:11:01.446 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r1_con
# 2026-05-25 11:11:01.520 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r2_con
# 2026-05-25 11:11:01.599 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] unrothum_r3_con
# 2026-05-25 11:11:01.675 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] shoulder1_r2_con
# 2026-05-25 11:11:01.744 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r1_con
# 2026-05-25 11:11:01.826 | INFO     | myoconverter.xml.parsers:parse:59 - [ConstraintParser: CoordinateCouplerConstraint] wrist_hand_r3_con
# 2026-05-25 11:11:01.903 | INFO     | myoconverter.xml.converter:_parse_bodies_and_joints:80 - Starting to parse bodies, wrapping objects, and joints
# 2026-05-25 11:11:01.904 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavicle
# 2026-05-25 11:11:01.911 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] sternoclavicular
# 2026-05-25 11:11:01.913 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] clavphant
# 2026-05-25 11:11:01.913 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] unrotscap
# 2026-05-25 11:11:01.915 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] scapula
# 2026-05-25 11:11:01.927 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Deltoid2
# 2026-05-25 11:11:01.927 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] Delt3
# 2026-05-25 11:11:01.928 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] INFSP
# 2026-05-25 11:11:01.929 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] TMIN
# 2026-05-25 11:11:01.929 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] TRIlongglen
# 2026-05-25 11:11:01.930 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] acromioclavicular
# 2026-05-25 11:11:01.931 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] scapphant
# 2026-05-25 11:11:01.932 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] unrothum
# 2026-05-25 11:11:01.934 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] humphant
# 2026-05-25 11:11:01.935 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] shoulder0
# 2026-05-25 11:11:01.936 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] humphant1
# 2026-05-25 11:11:01.937 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] shoulder1
# 2026-05-25 11:11:01.939 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] humerus
# 2026-05-25 11:11:01.986 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] DELT1hh
# 2026-05-25 11:11:01.987 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] delt2hum
# 2026-05-25 11:11:01.988 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] delt3hum
# 2026-05-25 11:11:01.988 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] SUPSP
# 2026-05-25 11:11:01.989 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] INFSP_and_TMIN_hum_head
# 2026-05-25 11:11:01.990 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] infsp_new
# 2026-05-25 11:11:01.991 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] SUBSCAP
# 2026-05-25 11:11:01.991 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] LIGhh_s
# 2026-05-25 11:11:01.992 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] LIGhh_mi
# 2026-05-25 11:11:01.992 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] TMINhum
# 2026-05-25 11:11:01.993 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] TMAJ_LAThum
# 2026-05-25 11:11:01.994 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] PEC12hum
# 2026-05-25 11:11:01.994 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapSphere] PEC23hh
# 2026-05-25 11:11:01.996 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] PEC1hh
# 2026-05-25 11:11:01.996 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] PEC3hum
# 2026-05-25 11:11:01.997 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] LAT_TMAJhh
# 2026-05-25 11:11:01.998 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapSphere] LAT_TMAJ2hh
# 2026-05-25 11:11:01.998 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Elbow_BIC_BRD
# 2026-05-25 11:11:01.999 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] TRIlonghh
# 2026-05-25 11:11:01.999 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] TRI
# 2026-05-25 11:11:02.000 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] ANC
# 2026-05-25 11:11:02.001 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] BIClong
# 2026-05-25 11:11:02.002 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapSphere] TMAJ_LAT_PEC_CORBhh
# 2026-05-25 11:11:02.003 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapSphere] DELT_TMAJ_LAT_PEC_CORBhh
# 2026-05-25 11:11:02.003 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] CORBhum
# 2026-05-25 11:11:02.004 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Elbow_PT_ECRL
# 2026-05-25 11:11:02.005 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] shoulder2
# 2026-05-25 11:11:02.006 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] ulna
# 2026-05-25 11:11:02.013 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] PQ2
# 2026-05-25 11:11:02.014 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] elbow
# 2026-05-25 11:11:02.015 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] radius
# 2026-05-25 11:11:02.023 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] SUP
# 2026-05-25 11:11:02.023 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] ECU
# 2026-05-25 11:11:02.024 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] PQ1
# 2026-05-25 11:11:02.025 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] radioulnar
# 2026-05-25 11:11:02.026 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] proximal_row
# 2026-05-25 11:11:02.120 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] Extensor_ellipse
# 2026-05-25 11:11:02.121 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] ECRL
# 2026-05-25 11:11:02.122 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] ECRB
# 2026-05-25 11:11:02.123 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] FCR
# 2026-05-25 11:11:02.124 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] FCU
# 2026-05-25 11:11:02.124 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] PL
# 2026-05-25 11:11:02.125 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] FDS
# 2026-05-25 11:11:02.126 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] FDP
# 2026-05-25 11:11:02.127 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] EDCL
# 2026-05-25 11:11:02.127 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] EDCR
# 2026-05-25 11:11:02.128 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] EDCM
# 2026-05-25 11:11:02.129 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapTorus] EDCI
# 2026-05-25 11:11:02.130 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] EDM
# 2026-05-25 11:11:02.131 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] FPL
# 2026-05-25 11:11:02.131 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] radiocarpal
# 2026-05-25 11:11:02.137 | INFO     | myoconverter.xml.parsers:parse:59 - [BodyParser: Body] hand
# 2026-05-25 11:11:02.578 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _2rdmcp_FDS
# 2026-05-25 11:11:02.579 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _2rdmcp_FDP
# 2026-05-25 11:11:02.580 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _2rdmcp_ext
# 2026-05-25 11:11:02.581 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapEllipsoid] _2ndmcp
# 2026-05-25 11:11:02.582 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _3rdmcp_FDS
# 2026-05-25 11:11:02.583 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _3rdmcp_FDP
# 2026-05-25 11:11:02.583 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _3rdmcp_ext
# 2026-05-25 11:11:02.585 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _4rdmcp_FDS
# 2026-05-25 11:11:02.585 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _4rdmcp_FDP
# 2026-05-25 11:11:02.586 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _4rdmcp_ext
# 2026-05-25 11:11:02.587 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _5rdmcp_FDS
# 2026-05-25 11:11:02.587 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _5rdmcp_FDP
# 2026-05-25 11:11:02.588 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] _5rdmcp_ext
# 2026-05-25 11:11:02.589 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Secondpm_FDS
# 2026-05-25 11:11:02.590 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Secondpm_FDP
# 2026-05-25 11:11:02.591 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Secondpm_ext
# 2026-05-25 11:11:02.591 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Secondmd_flex
# 2026-05-25 11:11:02.592 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Secondmd_ext
# 2026-05-25 11:11:02.593 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Secondpm
# 2026-05-25 11:11:02.593 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Secondmd
# 2026-05-25 11:11:02.594 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] MPthumb
# 2026-05-25 11:11:02.595 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] IPthumb
# 2026-05-25 11:11:02.596 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Thirdpm_FDS
# 2026-05-25 11:11:02.596 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Thirdpm_FDP
# 2026-05-25 11:11:02.597 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Thirdpm_ext
# 2026-05-25 11:11:02.598 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Thirdmd_flex
# 2026-05-25 11:11:02.599 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Thirdmd_ext
# 2026-05-25 11:11:02.599 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fourthpm_FDS
# 2026-05-25 11:11:02.600 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fourthpm_FDP
# 2026-05-25 11:11:02.601 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fourthpm_ext
# 2026-05-25 11:11:02.602 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fourthmd_flex
# 2026-05-25 11:11:02.603 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fourthmd_ext
# 2026-05-25 11:11:02.603 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fifthpm_FDS
# 2026-05-25 11:11:02.604 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fifthpm_FDP
# 2026-05-25 11:11:02.605 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fifthpm_ext
# 2026-05-25 11:11:02.606 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fifthmd_flex
# 2026-05-25 11:11:02.606 | INFO     | myoconverter.xml.parsers:parse:59 - [WrapObjectParser: WrapCylinder] Fifthmd_ext
# 2026-05-25 11:11:02.607 | INFO     | myoconverter.xml.parsers:parse:59 - [JointParser: CustomJoint] wrist_hand
# 2026-05-25 11:11:02.609 | INFO     | myoconverter.xml.converter:_parse_forces:156 - Starting to parse forces, including path points and wrap paths
# 2026-05-25 11:11:02.609 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Ligament] s_glenohum
# 2026-05-25 11:11:02.610 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] s_glenohum-P1
# 2026-05-25 11:11:02.611 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] s_glenohum-P2
# 2026-05-25 11:11:02.611 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.612 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.615 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Ligament] m_glenohum
# 2026-05-25 11:11:02.615 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] m_glenohum-P1
# 2026-05-25 11:11:02.616 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] m_glenohum-P2
# 2026-05-25 11:11:02.617 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.617 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.620 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Ligament] i_glenohum
# 2026-05-25 11:11:02.620 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] i_glenohum-P1
# 2026-05-25 11:11:02.621 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] i_glenohum-P2
# 2026-05-25 11:11:02.621 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.622 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.624 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Ligament] coracohum
# 2026-05-25 11:11:02.626 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] coracohum-P1
# 2026-05-25 11:11:02.626 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] coracohum-P2
# 2026-05-25 11:11:02.627 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.627 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.630 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] shoulder_elv_ligaments
# 2026-05-25 11:11:02.631 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping shoulder_elv_ligaments
# 2026-05-25 11:11:02.631 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] shoulder_elv_damping
# 2026-05-25 11:11:02.632 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping shoulder_elv_damping
# 2026-05-25 11:11:02.632 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] elv_angle_ligaments
# 2026-05-25 11:11:02.633 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping elv_angle_ligaments
# 2026-05-25 11:11:02.633 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] elv_angle_damping
# 2026-05-25 11:11:02.634 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping elv_angle_damping
# 2026-05-25 11:11:02.634 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] shoulder_rot_ligaments
# 2026-05-25 11:11:02.635 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping shoulder_rot_ligaments
# 2026-05-25 11:11:02.635 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] shoulder_rot_damping
# 2026-05-25 11:11:02.636 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping shoulder_rot_damping
# 2026-05-25 11:11:02.637 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] elbow_flexion_ligaments
# 2026-05-25 11:11:02.637 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping elbow_flexion_ligaments
# 2026-05-25 11:11:02.638 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] elbow_flexion_damping
# 2026-05-25 11:11:02.638 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping elbow_flexion_damping
# 2026-05-25 11:11:02.639 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] pro_sup_ligaments
# 2026-05-25 11:11:02.639 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping pro_sup_ligaments
# 2026-05-25 11:11:02.640 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] pro_sup_damping
# 2026-05-25 11:11:02.640 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping pro_sup_damping
# 2026-05-25 11:11:02.641 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] deviation_ligaments
# 2026-05-25 11:11:02.641 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping deviation_ligaments
# 2026-05-25 11:11:02.642 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] deviation_damping
# 2026-05-25 11:11:02.642 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping deviation_damping
# 2026-05-25 11:11:02.643 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] flexion_ligaments
# 2026-05-25 11:11:02.644 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping flexion_ligaments
# 2026-05-25 11:11:02.645 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: CoordinateLimitForce] flexion_damping
# 2026-05-25 11:11:02.645 | WARNING  | myoconverter.xml.forces.CoordinateLimitForce:parse:30 - CoordinateLimitForce parsing not implemented, skipping flexion_damping
# 2026-05-25 11:11:02.646 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] DELT1
# 2026-05-25 11:11:02.646 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT1-P1
# 2026-05-25 11:11:02.647 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT1-P2
# 2026-05-25 11:11:02.648 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT1-P3
# 2026-05-25 11:11:02.648 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT1-P4
# 2026-05-25 11:11:02.649 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.649 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.653 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-25 11:11:02.656 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] DELT2
# 2026-05-25 11:11:02.657 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT2-P1
# 2026-05-25 11:11:02.657 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default
# 2026-05-25 11:11:02.914 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT2-P3
# 2026-05-25 11:11:02.915 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT2-P4
# 2026-05-25 11:11:02.915 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.916 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.918 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-25 11:11:02.919 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-05-25 11:11:02.921 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] DELT3
# 2026-05-25 11:11:02.922 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT3-P1
# 2026-05-25 11:11:02.922 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT3-P2
# 2026-05-25 11:11:02.922 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] DELT3-P3
# 2026-05-25 11:11:02.923 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.924 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.925 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-25 11:11:02.927 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-05-25 11:11:02.928 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] SUPSP
# 2026-05-25 11:11:02.929 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUPSP-P1
# 2026-05-25 11:11:02.929 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUPSP-P2
# 2026-05-25 11:11:02.930 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUPSP-P3
# 2026-05-25 11:11:02.930 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.931 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.933 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] INFSP
# 2026-05-25 11:11:02.933 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] INFSP-P1
# 2026-05-25 11:11:02.934 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] INFSP-P2
# 2026-05-25 11:11:02.934 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.935 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.936 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-25 11:11:02.938 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] SUBSC
# 2026-05-25 11:11:02.938 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUBSC-P1
# 2026-05-25 11:11:02.939 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUBSC-P2
# 2026-05-25 11:11:02.939 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] SUBSC-P3
# 2026-05-25 11:11:02.940 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.940 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.942 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] TMIN
# 2026-05-25 11:11:02.943 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TMIN-P1
# 2026-05-25 11:11:02.943 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TMIN-P2
# 2026-05-25 11:11:02.944 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TMIN-P3
# 2026-05-25 11:11:02.944 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:02.945 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:02.946 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-25 11:11:02.948 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-05-25 11:11:02.949 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] TMAJ
# 2026-05-25 11:11:02.950 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TMAJ-P1
# 2026-05-25 11:11:02.950 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] default
# 2026-05-25 11:11:03.198 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: ConditionalPathPoint] default_0
# 2026-05-25 11:11:03.444 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TMAJ-P2
# 2026-05-25 11:11:03.445 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] TMAJ-P3
# 2026-05-25 11:11:03.445 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapSetParser: PathWrapSet]
# 2026-05-25 11:11:03.446 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap
# 2026-05-25 11:11:03.448 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_0
# 2026-05-25 11:11:03.450 | INFO     | myoconverter.xml.parsers:parse:59 - [PathWrapParser: PathWrap] pathwrap_1
# 2026-05-25 11:11:03.452 | INFO     | myoconverter.xml.parsers:parse:59 - [ForceParser: Millard2012EquilibriumMuscle] PECM1
# 2026-05-25 11:11:03.452 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: PathPoint] PECM1-P1
# 2026-05-25 11:11:03.453 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default
# 2026-05-25 11:11:03.803 | INFO     | myoconverter.xml.parsers:parse:59 - [PathPointParser: MovingPathPoint] default_0

# %%
pipeline_output.show()

# %%
print(1)

# %%
output_dir_path
# Out:
# '/mnt/ext1/seojin/temp/MOBL_ARMS_41'
