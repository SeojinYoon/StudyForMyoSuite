# %% [markdown]
# # Common Libraries

# %%
import os, shutil, sys
if shutil.which('nvidia-smi') is not None:
    os.environ['MUJOCO_GL'] = 'egl'
import mujoco, mujoco.viewer

from loop_rate_limiters import RateLimiter
import numpy as np
from mink import (
    Configuration,
    FrameTask,
    PostureTask,
    SE3, 
    SO3,
    solve_ik
)
import mediapy as media
import matplotlib.pylab as plt

# %% [markdown]
# # Custom Libraries

# %%
sys.path.append("/home/seojin/Seojin_commonTool/Module")
from sj_datastructure import make_3d_dataset
from sj_visualization import plot_3D_dataset

sys.path.append("/home/seojin/StudyForMyoSuite/Mink/IK_arm")
from tool import do_IK

# %% [markdown]
# # Params

# %%
myosim_dir_path = "/home/seojin/myosuite/myosuite/simhive/myo_sim/arm"

# Simulation parameters
duration = 2.0  # seconds
fps = 60
n_frames = int(duration * fps)
dt = 1.0 / fps

solver = "quadprog"
pos_threshold = 1e-4
ori_threshold = 1e-4
max_iters = 20

# %% [markdown]
# # Model specification

# %%
os.chdir(myosim_dir_path)

model_name = "myoarm.xml"
xml_string = f"""
        <mujoco model="MyoArm with Mocap">
            <include file="{model_name}"/>
            <worldbody>
                <body name="target" pos="0 0 0" quat="0 1 0 0" mocap="true">
                    <geom type="box" size=".15 .15 .15" contype="0" conaffinity="0" rgba=".6 .3 .3 .2"/>
                </body>
            </worldbody>
        </mujoco>
        """

# %% [markdown]
# # Initialize model & data

# %%
model_path = os.path.join(myosim_dir_path, model_name)
model = mujoco.MjModel.from_xml_path(model_path)
data = mujoco.MjData(model)

# %% [markdown]
# # IK configuration

# %%
configuration = Configuration(model)
origin_target = configuration.get_transform_frame_to_world("S_grasp", "site")
origin_target_orientation = origin_target.wxyz_xyz[:4]
origin_target_position = origin_target.wxyz_xyz[4:]

# Task
end_effector_task = FrameTask(
    frame_name="S_grasp",
    frame_type="site",
    position_cost=1.0,
    orientation_cost=1.0,
)

# Renderer
renderer = mujoco.Renderer(configuration.model, height=400, width=600)

# %% [markdown]
# # Target

# %%
# Make target trajectory: move the end-effector in a circular path.
center_point = origin_target_position
r = 0.2
start_angle = 0
end_angle = 2 * np.pi

angles = np.linspace(start_angle, end_angle, n_frames)
target_translations_circular = np.zeros((n_frames, 3))
target_translations_circular[:, 0] = center_point[0] + r * np.cos(angles)
target_translations_circular[:, 1] = center_point[1] + r * np.sin(angles)
target_translations_circular[:, 2] = center_point[2]

target_orientations = np.tile(origin_target_orientation, (n_frames, 1))
target_move_circular = np.concatenate((target_orientations, target_translations_circular), axis=1)

# %% [markdown]
# # Visualize expected end effector position

# %%
ef_ds = make_3d_dataset(data = np.expand_dims(target_translations_circular[:, [0, 2, 1]], 1),
                        wrapping_dataset_name = "3D",
                        element_dataset_names = ["Times", "Labels", "Coords"],
                        dataset1_dim_names = np.arange(n_frames),
                        dataset2_dim_names = ["EF"],
                        dataset3_dim_names = ["X", "Y", "Z"])

# %%
plot_3D_dataset(ef_ds)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Do inverse kinematics

# %%
# Params
solver_name = "quadprog"
limits = []

# Scence options
scene_option = mujoco.MjvOption()

# Camera setting
camera = mujoco.MjvCamera()
camera.type = mujoco.mjtCamera.mjCAMERA_FREE
camera.distance = 4

# Do inverse kinematics
ee_positions = []
frames = []
for frame_i in range(n_frames):
    # Set target
    target_val = target_move_circular[frame_i] # [w_o, x_o, y_o, z_o ,x,y,z]
    new_target = SE3(wxyz_xyz = target_val)
    end_effector_task.set_target(new_target)
    #configuration.data.mocap_pos[0] = new_target.wxyz_xyz[4:]
    #configuration.data.mocap_quat[0] = new_target.wxyz_xyz[:4]
            
    # Perform inverse kinematics
    tasks = [ end_effector_task ]
    vel = solve_ik(configuration, tasks, dt, solver=solver_name, limits = limits)
    configuration.integrate_inplace(vel, dt)
    
    # Update the physical state of the simulation
    mujoco.mj_forward(configuration.model, configuration.data)

    site_id = mujoco.mj_name2id(configuration.model, mujoco.mjtObj.mjOBJ_SITE, "S_grasp")
    ee_pos = configuration.data.site_xpos[site_id].copy() # 값의 변형 방지를 위해 copy 권장
    ee_positions.append(ee_pos)

    # Save the current frame for video
    # renderer.update_scene(configuration.data, scene_option=scene_option)
    renderer.update_scene(configuration.data, camera=camera, scene_option=scene_option)
    
    pixels = renderer.render()
    frames.append(pixels)

# %% [markdown]
# # Show video

# %%
media.show_video(frames, fps = fps, loop = False)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="600" height="400" style="object-fit:cover;" autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# # IK - Error

# %%
ee_positions, target = np.array(ee_positions), target_move_circular[:, 4:]
total_error = np.sum((ee_positions - target) ** 2, axis = 1)
plt.plot(total_error)
